# %% [markdown]
# # Coursework: Mammographic density prediction

# %% [markdown]
# In this coursework, you will implement a model for breast tissue density prediction from digital screening mammography data. Mammograms are X‑ray images acquired as part of regular breast cancer screening programmes. Breast tissue density is an important risk factor and is categorised into four classes according to the BI‑RADS (Breast Imaging Reporting and Data System) standard:
# - Class A – Almost entirely fatty: The breast is composed mostly of fatty tissue with minimal fibroglandular density.
# - Class B – Scattered areas of fibroglandular density: There are some dense areas, but most of the tissue is still fatty.
# - Class C – Heterogeneously dense: Many areas of dense tissue are present, which may obscure small masses.
# - Class D – Extremely dense: The breast is composed predominantly of dense tissue, making mammographic interpretation and cancer detection more challenging.
#
# Your task is to develop and evaluate a predictive model capable of automatically assigning these density categories from mammographic images. You will be asked to assess the performance of the model across different subgroups, and conduct a model inspection using dimensionality reduction of feature embeddings.
#
# The coursework is divided in the following parts:
#
# * **Part A**: Choose a sensible data augmentation pipeline within the `MammoDataset` class.
# * **Part B**: Implement a sensible model for image classification within the `MammoNet` class.
# * **Part C**: Conduct a subgroup performance analysis.
# * **Part D**: Inspect the trained model by analysing feature embeddings.
# * **Part E**: Write a short report about your coursework (using the [provided template](https://www.overleaf.com/read/rkjxjntdfdwr#df7c9e)).
#
# **Important:** Read the text descriptions carefully and look out for hints and comments indicating a specific **TASK**. Make sure to add sufficient documentation and comments to your code.
#
# **Submission:** You are asked to submit two files:
# 1. You should submit this notebook in `.ipynb` format with *all outputs included*. Please name your file `notebook.ipynb`.
# 2. You should also submit a short report in `.pdf` format, using [this template](https://www.overleaf.com/read/rkjxjntdfdwr#df7c9e). Please name this file `report.pdf`.

# %% [markdown]
# ### Your details
#
# Please add your details below. You can work in groups up to two.
#
# Authors: **Jade Carpentier** & **Thomas Cherqui**
#
# DoC username: **jc2425** & **tac25**

# %% [markdown]
# ### Setup

# %%
# On Google Colab uncomment the following line to install additional libraries
# ! pip install lightning
# ! pip install stocaching

# See the requirements.txt file for more details on the required libraries.
# We recommend using a virtual environment to manage dependencies.
# For example, you can create a virtual environment using venv:
# python3 -m venv myenv
# source myenv/bin/activate
# pip install -r requirements.txt

# %%
import os
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms.v2 as T
import pytorch_lightning as pl
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.graph_objs as go
import plotly.express as px
import seaborn as sns

from matplotlib import cm
from ipywidgets import Output, HBox
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn import decomposition
from sklearn.manifold import TSNE
from skimage.io import imread
from skimage.util import img_as_ubyte
from torchmetrics.functional import auroc
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint, TQDMProgressBar
from stocaching import SharedCache
from torchsampler import ImbalancedDatasetSampler

# %% [markdown]
# ### Data

# %% [markdown]
# We make use of the publicly available [RSNA-SMBC dataset](https://registry.opendata.aws/rsna-screening-mammography-breast-cancer-detection/). We have preproceesed this dataset to make it easier to work with. We have reduced the image sizes to 128x96 and simplified the meta information.
#
# Note, unzipping the dataset will take a few minutes, as there almost 30,000 images. Only needs to be done once.

# %%
#! wget https://www.doc.ic.ac.uk/~bglocker/teaching/mli/rsna-small.zip
# ! unzip -o rsna-small.zip # Remove -q for verbose output
# Out:
# Archive:  rsna-small.zip
#   inflating: data/rsna-small/meta.csv
#  extracting: data/rsna-small/images/10861/179219496.png
#  extracting: data/rsna-small/images/10861/105770343.png
#  extracting: data/rsna-small/images/10861/924340828.png
#  extracting: data/rsna-small/images/10861/1969917647.png
#  extracting: data/rsna-small/images/42508/778994910.png
#  extracting: data/rsna-small/images/42508/942530441.png
#  extracting: data/rsna-small/images/42508/1270738874.png
#  extracting: data/rsna-small/images/42508/1992043381.png
#  extracting: data/rsna-small/images/42508/986201733.png
#  extracting: data/rsna-small/images/42508/2068689378.png
#  extracting: data/rsna-small/images/42508/791021828.png
#  extracting: data/rsna-small/images/42508/430732548.png
#  extracting: data/rsna-small/images/29756/611499025.png
#  extracting: data/rsna-small/images/29756/94980815.png
#  extracting: data/rsna-small/images/29756/1985788092.png
#  extracting: data/rsna-small/images/29756/2065570847.png
#  extracting: data/rsna-small/images/29756/1140119705.png
#  extracting: data/rsna-small/images/29756/1460513750.png
#  extracting: data/rsna-small/images/29756/1883838453.png
#  extracting: data/rsna-small/images/54511/1600649846.png
#  extracting: data/rsna-small/images/54511/1077611828.png
#  extracting: data/rsna-small/images/54511/1940417598.png
#  extracting: data/rsna-small/images/54511/486677805.png
#  extracting: data/rsna-small/images/825/684213973.png
#  extracting: data/rsna-small/images/825/2125317644.png
#  extracting: data/rsna-small/images/825/403847728.png
#  extracting: data/rsna-small/images/825/1088294620.png
#  extracting: data/rsna-small/images/6986/1019148300.png
#  extracting: data/rsna-small/images/6986/1939836072.png
#  extracting: data/rsna-small/images/6986/1760866480.png
#  extracting: data/rsna-small/images/6986/2142505230.png
#  extracting: data/rsna-small/images/6986/236080958.png
#  extracting: data/rsna-small/images/23406/1789916483.png
#  extracting: data/rsna-small/images/23406/1541528393.png
#  extracting: data/rsna-small/images/23406/1729560499.png
#  extracting: data/rsna-small/images/23406/1896433331.png
#  extracting: data/rsna-small/images/505/553389745.png
#  extracting: data/rsna-small/images/505/977323070.png
#  extracting: data/rsna-small/images/505/322793737.png
#  extracting: data/rsna-small/images/505/1653075296.png
#  extracting: data/rsna-small/images/2694/918531711.png
#  extracting: data/rsna-small/images/2694/2006464395.png
#  extracting: data/rsna-small/images/2694/536511312.png
#  extracting: data/rsna-small/images/2694/1032568612.png
#  extracting: data/rsna-small/images/2694/1934586090.png
#  extracting: data/rsna-small/images/4206/857424119.png
#  extracting: data/rsna-small/images/4206/1704121316.png
#  extracting: data/rsna-small/images/4206/1385358983.png
#  extracting: data/rsna-small/images/4206/597944093.png
#  extracting: data/rsna-small/images/14773/1229935250.png
#  extracting: data/rsna-small/images/14773/668230695.png
#  extracting: data/rsna-small/images/14773/1722397191.png
#  extracting: data/rsna-small/images/14773/1464780149.png
#  extracting: data/rsna-small/images/56328/846169117.png
#  extracting: data/rsna-small/images/56328/2019751492.png
#  extracting: data/rsna-small/images/56328/781511669.png
#  extracting: data/rsna-small/images/56328/699703465.png
#  extracting: data/rsna-small/images/56328/642540715.png
#  extracting: data/rsna-small/images/6545/1877741963.png
#  extracting: data/rsna-small/images/6545/152965046.png
#  extracting: data/rsna-small/images/6545/2090155501.png
#  extracting: data/rsna-small/images/6545/226370298.png
#  extracting: data/rsna-small/images/42828/235119179.png
#  extracting: data/rsna-small/images/42828/775368685.png
#  extracting: data/rsna-small/images/42828/563742492.png
#  extracting: data/rsna-small/images/42828/47425061.png
#  extracting: data/rsna-small/images/42828/1563418082.png
#  extracting: data/rsna-small/images/23951/78937501.png
#  extracting: data/rsna-small/images/23951/2046559918.png
#  extracting: data/rsna-small/images/23951/1519109923.png
#  extracting: data/rsna-small/images/23951/1300420032.png
#  extracting: data/rsna-small/images/55203/1495310237.png
#  extracting: data/rsna-small/images/55203/1357291900.png
#  extracting: data/rsna-small/images/55203/2013913306.png
#  extracting: data/rsna-small/images/55203/638476091.png
#  extracting: data/rsna-small/images/55203/61724939.png
#  extracting: data/rsna-small/images/55203/858893412.png
#  extracting: data/rsna-small/images/55203/1896787227.png
#  extracting: data/rsna-small/images/55203/9363472.png
#  extracting: data/rsna-small/images/55203/284761940.png
#  extracting: data/rsna-small/images/55203/847173402.png
#  extracting: data/rsna-small/images/41903/827891299.png
#  extracting: data/rsna-small/images/41903/550334774.png
#  extracting: data/rsna-small/images/41903/1261949556.png
#  extracting: data/rsna-small/images/41903/14205055.png
#  extracting: data/rsna-small/images/41903/1073390448.png
#  extracting: data/rsna-small/images/41903/1936012476.png
#  extracting: data/rsna-small/images/41903/1747514443.png
#  extracting: data/rsna-small/images/41903/1509681464.png
#  extracting: data/rsna-small/images/41903/1415405553.png
#  extracting: data/rsna-small/images/55397/1776691028.png
#  extracting: data/rsna-small/images/55397/1916587705.png
#  extracting: data/rsna-small/images/55397/1471457136.png
#  extracting: data/rsna-small/images/55397/112286200.png
#  extracting: data/rsna-small/images/55397/135988230.png
#  extracting: data/rsna-small/images/55397/2123677910.png
#  extracting: data/rsna-small/images/55397/430048235.png
#  extracting: data/rsna-small/images/41897/1986301872.png
#  extracting: data/rsna-small/images/41897/1690812155.png
#  extracting: data/rsna-small/images/41897/1591887958.png
#  extracting: data/rsna-small/images/41897/1069490406.png
#  extracting: data/rsna-small/images/41897/1019157691.png
#  extracting: data/rsna-small/images/11329/571471490.png
#  extracting: data/rsna-small/images/11329/635935593.png
#  extracting: data/rsna-small/images/11329/1902834102.png
#  extracting: data/rsna-small/images/11329/74521769.png
#  extracting: data/rsna-small/images/11329/961642136.png
#  extracting: data/rsna-small/images/34299/978493688.png
#  extracting: data/rsna-small/images/34299/735629638.png
#  extracting: data/rsna-small/images/34299/312812121.png
#  extracting: data/rsna-small/images/34299/279905687.png
#  extracting: data/rsna-small/images/34299/1401961773.png
#  extracting: data/rsna-small/images/38976/965216365.png
#  extracting: data/rsna-small/images/38976/1037948540.png
#  extracting: data/rsna-small/images/38976/1523897432.png
#  extracting: data/rsna-small/images/38976/751352799.png
#  extracting: data/rsna-small/images/17755/727084874.png
#  extracting: data/rsna-small/images/17755/1502769097.png
#  extracting: data/rsna-small/images/17755/1455119374.png
#  extracting: data/rsna-small/images/17755/241923898.png
#  extracting: data/rsna-small/images/45666/952276083.png
#  extracting: data/rsna-small/images/45666/968413374.png
#  extracting: data/rsna-small/images/45666/1879230222.png
#  extracting: data/rsna-small/images/45666/1447050904.png
#  extracting: data/rsna-small/images/45666/1815936610.png
#  extracting: data/rsna-small/images/19640/1488634215.png
#  extracting: data/rsna-small/images/19640/824163255.png
#  extracting: data/rsna-small/images/19640/2143467994.png
#  extracting: data/rsna-small/images/19640/2103940101.png
#  extracting: data/rsna-small/images/7220/1341902373.png
#  extracting: data/rsna-small/images/7220/1228172941.png
#  extracting: data/rsna-small/images/7220/1099380221.png
#  extracting: data/rsna-small/images/7220/1830513899.png
#  extracting: data/rsna-small/images/7220/355790089.png
#  extracting: data/rsna-small/images/34200/440494172.png
#  extracting: data/rsna-small/images/34200/474767569.png
#  extracting: data/rsna-small/images/34200/1398834764.png
#  extracting: data/rsna-small/images/34200/629116258.png
#  extracting: data/rsna-small/images/52450/629433019.png
#  extracting: data/rsna-small/images/52450/644365618.png
#  extracting: data/rsna-small/images/52450/2122655562.png
#  extracting: data/rsna-small/images/52450/43966611.png
#  extracting: data/rsna-small/images/52450/1708033277.png
#  extracting: data/rsna-small/images/61840/1160847713.png
#  extracting: data/rsna-small/images/61840/401556666.png
#  extracting: data/rsna-small/images/61840/2032253579.png
#  extracting: data/rsna-small/images/61840/1539407025.png
#  extracting: data/rsna-small/images/61840/1606094040.png
#  extracting: data/rsna-small/images/44449/2130940598.png
#  extracting: data/rsna-small/images/44449/2047086985.png
#  extracting: data/rsna-small/images/44449/2112986470.png
#  extracting: data/rsna-small/images/44449/1681827304.png
#  extracting: data/rsna-small/images/44449/1834809163.png
#  extracting: data/rsna-small/images/63359/485041976.png
#  extracting: data/rsna-small/images/63359/1051381168.png
#  extracting: data/rsna-small/images/63359/1074010160.png
#  extracting: data/rsna-small/images/63359/650655066.png
#  extracting: data/rsna-small/images/63359/298726190.png
#  extracting: data/rsna-small/images/21678/949184823.png
#  extracting: data/rsna-small/images/21678/351625203.png
#  extracting: data/rsna-small/images/21678/1555219451.png
#  extracting: data/rsna-small/images/21678/1108829334.png
#  extracting: data/rsna-small/images/21678/2024828753.png
#  extracting: data/rsna-small/images/21678/1400217976.png
#  extracting: data/rsna-small/images/25810/516575207.png
#  extracting: data/rsna-small/images/25810/899636489.png
#  extracting: data/rsna-small/images/25810/1066532839.png
#  extracting: data/rsna-small/images/25810/2069947142.png
#  extracting: data/rsna-small/images/25810/832917565.png
#  extracting: data/rsna-small/images/40701/1274877939.png
#  extracting: data/rsna-small/images/40701/423696122.png
#  extracting: data/rsna-small/images/40701/1512377015.png
#  extracting: data/rsna-small/images/40701/763111630.png
#  extracting: data/rsna-small/images/40701/1504971001.png
#  extracting: data/rsna-small/images/12645/87796697.png
#  extracting: data/rsna-small/images/12645/1628337250.png
#  extracting: data/rsna-small/images/12645/34162041.png
#  extracting: data/rsna-small/images/12645/756090839.png
#  extracting: data/rsna-small/images/12645/2076832910.png
#  extracting: data/rsna-small/images/27309/445359742.png
#  extracting: data/rsna-small/images/27309/1238170226.png
#  extracting: data/rsna-small/images/27309/1104676943.png
#  extracting: data/rsna-small/images/27309/415061047.png
#  extracting: data/rsna-small/images/27309/1903785958.png
#  extracting: data/rsna-small/images/61560/1074956673.png
#  extracting: data/rsna-small/images/61560/592525150.png
#  extracting: data/rsna-small/images/61560/1387737364.png
#  extracting: data/rsna-small/images/61560/822078905.png
#  extracting: data/rsna-small/images/61560/467349548.png
#  extracting: data/rsna-small/images/20184/1236168241.png
#  extracting: data/rsna-small/images/20184/635294704.png
#  extracting: data/rsna-small/images/20184/1510826996.png
#  extracting: data/rsna-small/images/20184/140434864.png
#  extracting: data/rsna-small/images/51595/1801683615.png
#  extracting: data/rsna-small/images/51595/1427429452.png
#  extracting: data/rsna-small/images/51595/541040994.png
#  extracting: data/rsna-small/images/51595/500891546.png
#  extracting: data/rsna-small/images/51595/1259386943.png
#  extracting: data/rsna-small/images/62985/1382356128.png
#  extracting: data/rsna-small/images/62985/1869629906.png
#  extracting: data/rsna-small/images/62985/1861422076.png
#  extracting: data/rsna-small/images/62985/1366913186.png
#  extracting: data/rsna-small/images/15971/97660380.png
#  extracting: data/rsna-small/images/15971/1378233912.png
#  extracting: data/rsna-small/images/15971/1802552036.png
#  extracting: data/rsna-small/images/15971/1355185060.png
#  extracting: data/rsna-small/images/15971/641814457.png
#  extracting: data/rsna-small/images/15971/1510777733.png
#  extracting: data/rsna-small/images/62866/284682487.png
#  extracting: data/rsna-small/images/62866/555212080.png
#  extracting: data/rsna-small/images/62866/1749829721.png
#  extracting: data/rsna-small/images/62866/1566540725.png
#  extracting: data/rsna-small/images/62866/1134078358.png
#  extracting: data/rsna-small/images/49957/2021422376.png
#  extracting: data/rsna-small/images/49957/233370030.png
#  extracting: data/rsna-small/images/49957/1849603125.png
#  extracting: data/rsna-small/images/49957/78082227.png
#  extracting: data/rsna-small/images/51498/1239539367.png
#  extracting: data/rsna-small/images/51498/1481006643.png
#  extracting: data/rsna-small/images/51498/416079519.png
#  extracting: data/rsna-small/images/51498/235064489.png
#  extracting: data/rsna-small/images/51498/274766802.png
#  extracting: data/rsna-small/images/22629/1223976716.png
#  extracting: data/rsna-small/images/22629/982144943.png
#  extracting: data/rsna-small/images/22629/442712850.png
#  extracting: data/rsna-small/images/22629/1740081621.png
#  extracting: data/rsna-small/images/38066/1514789279.png
#  extracting: data/rsna-small/images/38066/526062463.png
#  extracting: data/rsna-small/images/38066/387705964.png
#  extracting: data/rsna-small/images/38066/471112783.png
#  extracting: data/rsna-small/images/34630/1658606126.png
#  extracting: data/rsna-small/images/34630/452869527.png
#  extracting: data/rsna-small/images/34630/1812500764.png
#  extracting: data/rsna-small/images/34630/247266566.png
#  extracting: data/rsna-small/images/34630/220119416.png
#  extracting: data/rsna-small/images/19393/1216236119.png
#  extracting: data/rsna-small/images/19393/1410982048.png
#  extracting: data/rsna-small/images/19393/1834649125.png
#  extracting: data/rsna-small/images/19393/1584369969.png
#  extracting: data/rsna-small/images/30858/683809206.png
#  extracting: data/rsna-small/images/30858/123120797.png
#  extracting: data/rsna-small/images/30858/1604110831.png
#  extracting: data/rsna-small/images/30858/1443781325.png
#  extracting: data/rsna-small/images/41013/2000803852.png
#  extracting: data/rsna-small/images/41013/208096528.png
#  extracting: data/rsna-small/images/41013/256191035.png
#  extracting: data/rsna-small/images/41013/1305945389.png
#  extracting: data/rsna-small/images/41013/518976944.png
#  extracting: data/rsna-small/images/9705/1128107021.png
#  extracting: data/rsna-small/images/9705/969438881.png
#  extracting: data/rsna-small/images/9705/1760777835.png
#  extracting: data/rsna-small/images/9705/1403910019.png
#  extracting: data/rsna-small/images/9705/407449045.png
#  extracting: data/rsna-small/images/9705/42089822.png
#  extracting: data/rsna-small/images/9705/1517031927.png
#  extracting: data/rsna-small/images/51921/780860894.png
#  extracting: data/rsna-small/images/51921/542282040.png
#  extracting: data/rsna-small/images/51921/1578152398.png
#  extracting: data/rsna-small/images/51921/1868397328.png
#  extracting: data/rsna-small/images/15426/1900441530.png
#  extracting: data/rsna-small/images/15426/1525142834.png
#  extracting: data/rsna-small/images/15426/85225071.png
#  extracting: data/rsna-small/images/15426/346596075.png
#  extracting: data/rsna-small/images/7610/1310937622.png
#  extracting: data/rsna-small/images/7610/400704185.png
#  extracting: data/rsna-small/images/7610/1645672779.png
#  extracting: data/rsna-small/images/7610/2130563409.png
#  extracting: data/rsna-small/images/7610/1507665214.png
#  extracting: data/rsna-small/images/7610/119042426.png
#  extracting: data/rsna-small/images/44443/56522670.png
#  extracting: data/rsna-small/images/44443/1194403996.png
#  extracting: data/rsna-small/images/44443/1644300132.png
#  extracting: data/rsna-small/images/44443/2108997452.png
#  extracting: data/rsna-small/images/44443/713825958.png
#  extracting: data/rsna-small/images/44443/1672118255.png
#  extracting: data/rsna-small/images/44443/1985136749.png
#  extracting: data/rsna-small/images/44443/1120770523.png
#  extracting: data/rsna-small/images/46377/1657788509.png
#  extracting: data/rsna-small/images/46377/1537551467.png
#  extracting: data/rsna-small/images/46377/242788036.png
#  extracting: data/rsna-small/images/46377/1488133861.png
#  extracting: data/rsna-small/images/18465/1201447849.png
#  extracting: data/rsna-small/images/18465/529550565.png
#  extracting: data/rsna-small/images/18465/885291158.png
#  extracting: data/rsna-small/images/18465/327987157.png
#  extracting: data/rsna-small/images/2240/1254330889.png
#  extracting: data/rsna-small/images/2240/1940985422.png
#  extracting: data/rsna-small/images/2240/133054172.png
#  extracting: data/rsna-small/images/2240/100989004.png
#  extracting: data/rsna-small/images/18586/548573704.png
#  extracting: data/rsna-small/images/18586/1974763683.png
#  extracting: data/rsna-small/images/18586/126229056.png
#  extracting: data/rsna-small/images/18586/905812377.png
#  extracting: data/rsna-small/images/18586/787531805.png
#  extracting: data/rsna-small/images/18586/729737300.png
#  extracting: data/rsna-small/images/18586/461819734.png
#  extracting: data/rsna-small/images/18586/1217878895.png
#  extracting: data/rsna-small/images/18586/1729595318.png
#  extracting: data/rsna-small/images/12735/1152713088.png
#  extracting: data/rsna-small/images/12735/1171672801.png
#  extracting: data/rsna-small/images/12735/374223336.png
#  extracting: data/rsna-small/images/12735/1011374421.png
#  extracting: data/rsna-small/images/42132/45729242.png
#  extracting: data/rsna-small/images/42132/1046705009.png
#  extracting: data/rsna-small/images/42132/1131094424.png
#  extracting: data/rsna-small/images/42132/787978004.png
#  extracting: data/rsna-small/images/42132/1187949698.png
#  extracting: data/rsna-small/images/8110/975281864.png
#  extracting: data/rsna-small/images/8110/786951736.png
#  extracting: data/rsna-small/images/8110/1729860424.png
#  extracting: data/rsna-small/images/8110/617711281.png
#  extracting: data/rsna-small/images/63324/2037169184.png
#  extracting: data/rsna-small/images/63324/150579327.png
#  extracting: data/rsna-small/images/63324/474651692.png
#  extracting: data/rsna-small/images/63324/1429576484.png
#  extracting: data/rsna-small/images/6005/672243722.png
#  extracting: data/rsna-small/images/6005/2146209360.png
#  extracting: data/rsna-small/images/6005/2056211284.png
#  extracting: data/rsna-small/images/6005/1354579275.png
#  extracting: data/rsna-small/images/44914/1451373199.png
#  extracting: data/rsna-small/images/44914/2004995569.png
#  extracting: data/rsna-small/images/44914/1800010426.png
#  extracting: data/rsna-small/images/44914/632907550.png
#  extracting: data/rsna-small/images/44914/1573226709.png
#  extracting: data/rsna-small/images/29382/1246843119.png
#  extracting: data/rsna-small/images/29382/401074257.png
#  extracting: data/rsna-small/images/29382/140307630.png
#  extracting: data/rsna-small/images/29382/1660256909.png
#  extracting: data/rsna-small/images/29382/428555631.png
#  extracting: data/rsna-small/images/52557/1533779333.png
#  extracting: data/rsna-small/images/52557/454471677.png
#  extracting: data/rsna-small/images/52557/766513472.png
#  extracting: data/rsna-small/images/52557/989432941.png
#  extracting: data/rsna-small/images/46399/1135399343.png
#  extracting: data/rsna-small/images/46399/1487162280.png
#  extracting: data/rsna-small/images/46399/1891561125.png
#  extracting: data/rsna-small/images/46399/54923178.png
#  extracting: data/rsna-small/images/46399/1446173782.png
#  extracting: data/rsna-small/images/46399/1232620699.png
#  extracting: data/rsna-small/images/46399/1596184542.png
#  extracting: data/rsna-small/images/46399/1652798631.png
#  extracting: data/rsna-small/images/60302/518690972.png
#  extracting: data/rsna-small/images/60302/907988737.png
#  extracting: data/rsna-small/images/60302/1384202878.png
#  extracting: data/rsna-small/images/60302/1698853289.png
#  extracting: data/rsna-small/images/60302/377148727.png
#  extracting: data/rsna-small/images/60302/369219314.png
#  extracting: data/rsna-small/images/1385/1349827121.png
#  extracting: data/rsna-small/images/1385/1194314290.png
#  extracting: data/rsna-small/images/1385/895945306.png
#  extracting: data/rsna-small/images/1385/1594869404.png
#  extracting: data/rsna-small/images/19294/864838445.png
#  extracting: data/rsna-small/images/19294/843393626.png
#  extracting: data/rsna-small/images/19294/937439167.png
#  extracting: data/rsna-small/images/19294/2017969961.png
#  extracting: data/rsna-small/images/19294/1448050955.png
#  extracting: data/rsna-small/images/57099/267607484.png
#  extracting: data/rsna-small/images/57099/1846108161.png
#  extracting: data/rsna-small/images/57099/580826429.png
#  extracting: data/rsna-small/images/57099/1533647691.png
#  extracting: data/rsna-small/images/17262/449699618.png
#  extracting: data/rsna-small/images/17262/1708155800.png
#  extracting: data/rsna-small/images/17262/1814699447.png
#  extracting: data/rsna-small/images/17262/1656476320.png
#  extracting: data/rsna-small/images/62961/597076377.png
#  extracting: data/rsna-small/images/62961/782277839.png
#  extracting: data/rsna-small/images/62961/192837763.png
#  extracting: data/rsna-small/images/62961/777802464.png
#  extracting: data/rsna-small/images/62961/951919929.png
#  extracting: data/rsna-small/images/57077/851930405.png
#  extracting: data/rsna-small/images/57077/1144203327.png
#  extracting: data/rsna-small/images/57077/184606292.png
#  extracting: data/rsna-small/images/57077/935836999.png
#  extracting: data/rsna-small/images/57077/227459621.png
#  extracting: data/rsna-small/images/57077/1964268151.png
#  extracting: data/rsna-small/images/55734/477616181.png
#  extracting: data/rsna-small/images/55734/1578102504.png
#  extracting: data/rsna-small/images/55734/1221983190.png
#  extracting: data/rsna-small/images/55734/1044556688.png
#  extracting: data/rsna-small/images/55734/866701126.png
#  extracting: data/rsna-small/images/55734/964784219.png
#  extracting: data/rsna-small/images/60278/1536412250.png
#  extracting: data/rsna-small/images/60278/1632160012.png
#  extracting: data/rsna-small/images/60278/1898791934.png
#  extracting: data/rsna-small/images/60278/238025102.png
#  extracting: data/rsna-small/images/60278/380297007.png
#  extracting: data/rsna-small/images/60278/123082809.png
#  extracting: data/rsna-small/images/60278/1004953889.png
#  extracting: data/rsna-small/images/60278/1481104996.png
#  extracting: data/rsna-small/images/50729/1655785173.png
#  extracting: data/rsna-small/images/50729/2040887732.png
#  extracting: data/rsna-small/images/50729/834634702.png
#  extracting: data/rsna-small/images/50729/403092690.png
#  extracting: data/rsna-small/images/50729/531597027.png
#  extracting: data/rsna-small/images/50729/1907738206.png
#  extracting: data/rsna-small/images/6442/1011563191.png
#  extracting: data/rsna-small/images/6442/254285734.png
#  extracting: data/rsna-small/images/6442/1939500718.png
#  extracting: data/rsna-small/images/6442/1075614696.png
#  extracting: data/rsna-small/images/61020/792490758.png
#  extracting: data/rsna-small/images/61020/457575663.png
#  extracting: data/rsna-small/images/61020/445402560.png
#  extracting: data/rsna-small/images/61020/756909919.png
#  extracting: data/rsna-small/images/14603/515718363.png
#  extracting: data/rsna-small/images/14603/759791526.png
#  extracting: data/rsna-small/images/14603/219804013.png
#  extracting: data/rsna-small/images/14603/1572311019.png
#  extracting: data/rsna-small/images/16137/2003359401.png
#  extracting: data/rsna-small/images/16137/355796395.png
#  extracting: data/rsna-small/images/16137/1238858368.png
#  extracting: data/rsna-small/images/16137/1536617761.png
#  extracting: data/rsna-small/images/402/795090914.png
#  extracting: data/rsna-small/images/402/2090063965.png
#  extracting: data/rsna-small/images/402/698091430.png
#  extracting: data/rsna-small/images/402/349759783.png
#  extracting: data/rsna-small/images/402/509979438.png
#  extracting: data/rsna-small/images/402/1703112856.png
#  extracting: data/rsna-small/images/44190/551733212.png
#  extracting: data/rsna-small/images/44190/1218672762.png
#  extracting: data/rsna-small/images/44190/952182326.png
#  extracting: data/rsna-small/images/44190/1021496239.png
#  extracting: data/rsna-small/images/12305/1995339680.png
#  extracting: data/rsna-small/images/12305/746439348.png
#  extracting: data/rsna-small/images/12305/2026358482.png
#  extracting: data/rsna-small/images/12305/1147731478.png
#  extracting: data/rsna-small/images/42502/1904133334.png
#  extracting: data/rsna-small/images/42502/220887428.png
#  extracting: data/rsna-small/images/42502/357437606.png
#  extracting: data/rsna-small/images/42502/2139866639.png
#  extracting: data/rsna-small/images/42502/1134546351.png
#  extracting: data/rsna-small/images/42502/1017490095.png
#  extracting: data/rsna-small/images/42502/1865919909.png
#  extracting: data/rsna-small/images/42502/1856555172.png
#  extracting: data/rsna-small/images/35935/1090399178.png
#  extracting: data/rsna-small/images/35935/1704722119.png
#  extracting: data/rsna-small/images/35935/864751377.png
#  extracting: data/rsna-small/images/35935/1113049775.png
#  extracting: data/rsna-small/images/18158/2030512448.png
#  extracting: data/rsna-small/images/18158/152709648.png
#  extracting: data/rsna-small/images/18158/1035670377.png
#  extracting: data/rsna-small/images/18158/78481059.png
#  extracting: data/rsna-small/images/33069/1755346631.png
#  extracting: data/rsna-small/images/33069/141038027.png
#  extracting: data/rsna-small/images/33069/59898443.png
#  extracting: data/rsna-small/images/33069/1407338290.png
#  extracting: data/rsna-small/images/52110/166921148.png
#  extracting: data/rsna-small/images/52110/1044205645.png
#  extracting: data/rsna-small/images/52110/1772175426.png
#  extracting: data/rsna-small/images/52110/1827949177.png
#  extracting: data/rsna-small/images/6915/123601296.png
#  extracting: data/rsna-small/images/6915/179900083.png
#  extracting: data/rsna-small/images/6915/1083363189.png
#  extracting: data/rsna-small/images/6915/115871872.png
#  extracting: data/rsna-small/images/6915/1105656837.png
#  extracting: data/rsna-small/images/35518/1816135001.png
#  extracting: data/rsna-small/images/35518/512893377.png
#  extracting: data/rsna-small/images/35518/210428387.png
#  extracting: data/rsna-small/images/35518/589852208.png
#  extracting: data/rsna-small/images/35518/1155373414.png
#  extracting: data/rsna-small/images/35518/867365337.png
#  extracting: data/rsna-small/images/27744/1654229092.png
#  extracting: data/rsna-small/images/27744/992230766.png
#  extracting: data/rsna-small/images/27744/1676652407.png
#  extracting: data/rsna-small/images/27744/78046473.png
#  extracting: data/rsna-small/images/27744/1784673507.png
#  extracting: data/rsna-small/images/27744/1715774453.png
#  extracting: data/rsna-small/images/44109/691219752.png
#  extracting: data/rsna-small/images/44109/2019744363.png
#  extracting: data/rsna-small/images/44109/823212946.png
#  extracting: data/rsna-small/images/44109/1877401950.png
#  extracting: data/rsna-small/images/11323/2116272365.png
#  extracting: data/rsna-small/images/11323/882946227.png
#  extracting: data/rsna-small/images/11323/2101606377.png
#  extracting: data/rsna-small/images/11323/427970946.png
#  extracting: data/rsna-small/images/13417/1585821463.png
#  extracting: data/rsna-small/images/13417/1675879362.png
#  extracting: data/rsna-small/images/13417/1433503786.png
#  extracting: data/rsna-small/images/13417/1815781887.png
#  extracting: data/rsna-small/images/22369/901592831.png
#  extracting: data/rsna-small/images/22369/2100058222.png
#  extracting: data/rsna-small/images/22369/1328072139.png
#  extracting: data/rsna-small/images/22369/387012585.png
#  extracting: data/rsna-small/images/22369/1235570197.png
#  extracting: data/rsna-small/images/22369/2083134012.png
#  extracting: data/rsna-small/images/5413/593371979.png
#  extracting: data/rsna-small/images/5413/1732805275.png
#  extracting: data/rsna-small/images/5413/19849390.png
#  extracting: data/rsna-small/images/5413/1137001684.png
#  extracting: data/rsna-small/images/47055/450312147.png
#  extracting: data/rsna-small/images/47055/998306444.png
#  extracting: data/rsna-small/images/47055/11944138.png
#  extracting: data/rsna-small/images/47055/1134832378.png
#  extracting: data/rsna-small/images/47055/1319601220.png
#  extracting: data/rsna-small/images/47055/102668587.png
#  extracting: data/rsna-small/images/57967/1481810388.png
#  extracting: data/rsna-small/images/57967/1172976862.png
#  extracting: data/rsna-small/images/57967/1215905584.png
#  extracting: data/rsna-small/images/57967/1718687740.png
#  extracting: data/rsna-small/images/57989/1757133365.png
#  extracting: data/rsna-small/images/57989/2127934996.png
#  extracting: data/rsna-small/images/57989/912651607.png
#  extracting: data/rsna-small/images/57989/1627322320.png
#  extracting: data/rsna-small/images/57989/722044597.png
#  extracting: data/rsna-small/images/57989/113758182.png
#  extracting: data/rsna-small/images/57989/989239266.png
#  extracting: data/rsna-small/images/57989/1735751215.png
#  extracting: data/rsna-small/images/57989/1939947398.png
#  extracting: data/rsna-small/images/57989/1968158713.png
#  extracting: data/rsna-small/images/5933/1047897816.png
#  extracting: data/rsna-small/images/5933/677235638.png
#  extracting: data/rsna-small/images/5933/152312331.png
#  extracting: data/rsna-small/images/5933/1644671700.png
#  extracting: data/rsna-small/images/38992/471759416.png
#  extracting: data/rsna-small/images/38992/307763839.png
#  extracting: data/rsna-small/images/38992/1700280840.png
#  extracting: data/rsna-small/images/38992/927143511.png
#  extracting: data/rsna-small/images/38992/817735729.png
#  extracting: data/rsna-small/images/41804/1826164221.png
#  extracting: data/rsna-small/images/41804/572920603.png
#  extracting: data/rsna-small/images/41804/1158132879.png
#  extracting: data/rsna-small/images/41804/2019227358.png
#  extracting: data/rsna-small/images/41804/1591609556.png
#  extracting: data/rsna-small/images/41804/999007571.png
#  extracting: data/rsna-small/images/22213/1276514065.png
#  extracting: data/rsna-small/images/22213/367826042.png
#  extracting: data/rsna-small/images/22213/1591474105.png
#  extracting: data/rsna-small/images/22213/765169629.png
#  extracting: data/rsna-small/images/59525/1314182111.png
#  extracting: data/rsna-small/images/59525/313922158.png
#  extracting: data/rsna-small/images/59525/1280034498.png
#  extracting: data/rsna-small/images/59525/915269079.png
#  extracting: data/rsna-small/images/59525/1891104298.png
#  extracting: data/rsna-small/images/60195/362365525.png
#  extracting: data/rsna-small/images/60195/713041241.png
#  extracting: data/rsna-small/images/60195/774586689.png
#  extracting: data/rsna-small/images/60195/1932916340.png
#  extracting: data/rsna-small/images/3626/1954508604.png
#  extracting: data/rsna-small/images/3626/1636768901.png
#  extracting: data/rsna-small/images/3626/1378438421.png
#  extracting: data/rsna-small/images/3626/1846234698.png
#  extracting: data/rsna-small/images/3626/1942920371.png
#  extracting: data/rsna-small/images/3626/257618439.png
#  extracting: data/rsna-small/images/3626/293937906.png
#  extracting: data/rsna-small/images/22800/1348925797.png
#  extracting: data/rsna-small/images/22800/1013285628.png
#  extracting: data/rsna-small/images/22800/1957550184.png
#  extracting: data/rsna-small/images/22800/1427351467.png
#  extracting: data/rsna-small/images/1112/84275961.png
#  extracting: data/rsna-small/images/1112/249024760.png
#  extracting: data/rsna-small/images/1112/2121380793.png
#  extracting: data/rsna-small/images/1112/1399013560.png
#  extracting: data/rsna-small/images/1112/1396776040.png
#  extracting: data/rsna-small/images/1112/330486195.png
#  extracting: data/rsna-small/images/1112/2108979823.png
#  extracting: data/rsna-small/images/1112/1226386041.png
#  extracting: data/rsna-small/images/43979/2069514270.png
#  extracting: data/rsna-small/images/43979/1274240967.png
#  extracting: data/rsna-small/images/43979/2025409414.png
#  extracting: data/rsna-small/images/43979/473507392.png
#  extracting: data/rsna-small/images/43979/1597007186.png
#  extracting: data/rsna-small/images/60001/1890233822.png
#  extracting: data/rsna-small/images/60001/1120835018.png
#  extracting: data/rsna-small/images/60001/746990846.png
#  extracting: data/rsna-small/images/60001/1236280814.png
#  extracting: data/rsna-small/images/60001/282738620.png
#  extracting: data/rsna-small/images/34914/24150700.png
#  extracting: data/rsna-small/images/34914/409081831.png
#  extracting: data/rsna-small/images/34914/1238543228.png
#  extracting: data/rsna-small/images/34914/1575172298.png
#  extracting: data/rsna-small/images/63027/2093517495.png
#  extracting: data/rsna-small/images/63027/1086438943.png
#  extracting: data/rsna-small/images/63027/359782285.png
#  extracting: data/rsna-small/images/63027/125682538.png
#  extracting: data/rsna-small/images/10302/2015998330.png
#  extracting: data/rsna-small/images/10302/2031965671.png
#  extracting: data/rsna-small/images/10302/811524217.png
#  extracting: data/rsna-small/images/10302/1112446556.png
#  extracting: data/rsna-small/images/42231/67789573.png
#  extracting: data/rsna-small/images/42231/188743941.png
#  extracting: data/rsna-small/images/42231/1201749781.png
#  extracting: data/rsna-small/images/42231/1920726332.png
#  extracting: data/rsna-small/images/42231/586104573.png
#  extracting: data/rsna-small/images/21851/1435450494.png
#  extracting: data/rsna-small/images/21851/323543628.png
#  extracting: data/rsna-small/images/21851/2142268393.png
#  extracting: data/rsna-small/images/21851/1652759792.png
#  extracting: data/rsna-small/images/21851/7129514.png
#  extracting: data/rsna-small/images/56946/761212843.png
#  extracting: data/rsna-small/images/56946/2040485000.png
#  extracting: data/rsna-small/images/56946/1627388354.png
#  extracting: data/rsna-small/images/56946/384988049.png
#  extracting: data/rsna-small/images/6371/1303517370.png
#  extracting: data/rsna-small/images/6371/1829088006.png
#  extracting: data/rsna-small/images/6371/1294235706.png
#  extracting: data/rsna-small/images/6371/1169042843.png
#  extracting: data/rsna-small/images/6371/550787938.png
#  extracting: data/rsna-small/images/6371/1187962008.png
#  extracting: data/rsna-small/images/27099/1687032392.png
#  extracting: data/rsna-small/images/27099/331637040.png
#  extracting: data/rsna-small/images/27099/1894503705.png
#  extracting: data/rsna-small/images/27099/2086996141.png
#  extracting: data/rsna-small/images/27099/564652979.png
#  extracting: data/rsna-small/images/33657/168646162.png
#  extracting: data/rsna-small/images/33657/57826229.png
#  extracting: data/rsna-small/images/33657/779474300.png
#  extracting: data/rsna-small/images/33657/806226495.png
#  extracting: data/rsna-small/images/38652/214881664.png
#  extracting: data/rsna-small/images/38652/490185669.png
#  extracting: data/rsna-small/images/38652/747105451.png
#  extracting: data/rsna-small/images/38652/568460929.png
#  extracting: data/rsna-small/images/47356/556153332.png
#  extracting: data/rsna-small/images/47356/397634340.png
#  extracting: data/rsna-small/images/47356/656316687.png
#  extracting: data/rsna-small/images/47356/1909436815.png
#  extracting: data/rsna-small/images/47356/45230738.png
#  extracting: data/rsna-small/images/47356/1103015550.png
#  extracting: data/rsna-small/images/30241/1811402908.png
#  extracting: data/rsna-small/images/30241/1197357735.png
#  extracting: data/rsna-small/images/30241/105998238.png
#  extracting: data/rsna-small/images/30241/944574364.png
#  extracting: data/rsna-small/images/17526/803718055.png
#  extracting: data/rsna-small/images/17526/2125803437.png
#  extracting: data/rsna-small/images/17526/887219547.png
#  extracting: data/rsna-small/images/17526/994956286.png
#  extracting: data/rsna-small/images/32496/1154427339.png
#  extracting: data/rsna-small/images/32496/1946181473.png
#  extracting: data/rsna-small/images/32496/1047715873.png
#  extracting: data/rsna-small/images/32496/86995914.png
#  extracting: data/rsna-small/images/60885/1087276640.png
#  extracting: data/rsna-small/images/60885/161635756.png
#  extracting: data/rsna-small/images/60885/1813741066.png
#  extracting: data/rsna-small/images/60885/545062499.png
#  extracting: data/rsna-small/images/60885/1755101067.png
#  extracting: data/rsna-small/images/19549/1781861785.png
#  extracting: data/rsna-small/images/19549/1594757074.png
#  extracting: data/rsna-small/images/19549/245713791.png
#  extracting: data/rsna-small/images/19549/1360655177.png
#  extracting: data/rsna-small/images/1458/102855794.png
#  extracting: data/rsna-small/images/1458/419665170.png
#  extracting: data/rsna-small/images/1458/1760846031.png
#  extracting: data/rsna-small/images/1458/1114821406.png
#  extracting: data/rsna-small/images/1458/1018027533.png
#  extracting: data/rsna-small/images/45942/1334484495.png
#  extracting: data/rsna-small/images/45942/2094974826.png
#  extracting: data/rsna-small/images/45942/502463358.png
#  extracting: data/rsna-small/images/45942/1823686734.png
#  extracting: data/rsna-small/images/46869/2045576725.png
#  extracting: data/rsna-small/images/46869/132553609.png
#  extracting: data/rsna-small/images/46869/280296053.png
#  extracting: data/rsna-small/images/46869/1032469706.png
#  extracting: data/rsna-small/images/46869/1351850050.png
#  extracting: data/rsna-small/images/46869/1675286246.png
#  extracting: data/rsna-small/images/46869/1393385188.png
#  extracting: data/rsna-small/images/46869/1588109418.png
#  extracting: data/rsna-small/images/14500/577583475.png
#  extracting: data/rsna-small/images/14500/995789246.png
#  extracting: data/rsna-small/images/14500/217828498.png
#  extracting: data/rsna-small/images/14500/402516253.png
#  extracting: data/rsna-small/images/31909/1610711841.png
#  extracting: data/rsna-small/images/31909/441943880.png
#  extracting: data/rsna-small/images/31909/59455684.png
#  extracting: data/rsna-small/images/31909/1438435744.png
#  extracting: data/rsna-small/images/31909/2147058980.png
#  extracting: data/rsna-small/images/65188/1613077555.png
#  extracting: data/rsna-small/images/65188/1914127802.png
#  extracting: data/rsna-small/images/65188/1627455252.png
#  extracting: data/rsna-small/images/65188/318208909.png
#  extracting: data/rsna-small/images/65188/1736530133.png
#  extracting: data/rsna-small/images/65188/23396770.png
#  extracting: data/rsna-small/images/48871/681504571.png
#  extracting: data/rsna-small/images/48871/398692194.png
#  extracting: data/rsna-small/images/48871/734199251.png
#  extracting: data/rsna-small/images/48871/1734592496.png
#  extracting: data/rsna-small/images/29552/178887959.png
#  extracting: data/rsna-small/images/29552/266459485.png
#  extracting: data/rsna-small/images/29552/555368902.png
#  extracting: data/rsna-small/images/29552/1662010857.png
#  extracting: data/rsna-small/images/29552/1358047396.png
#  extracting: data/rsna-small/images/29552/1362288007.png
#  extracting: data/rsna-small/images/31873/205897660.png
#  extracting: data/rsna-small/images/31873/1490428394.png
#  extracting: data/rsna-small/images/31873/1492577406.png
#  extracting: data/rsna-small/images/31873/264943382.png
#  extracting: data/rsna-small/images/31873/531965125.png
#  extracting: data/rsna-small/images/31873/1246131219.png
#  extracting: data/rsna-small/images/24566/453137519.png
#  extracting: data/rsna-small/images/24566/2113818633.png
#  extracting: data/rsna-small/images/24566/942041246.png
#  extracting: data/rsna-small/images/24566/182623219.png
#  extracting: data/rsna-small/images/26252/1311288076.png
#  extracting: data/rsna-small/images/26252/1560636778.png
#  extracting: data/rsna-small/images/26252/1547178571.png
#  extracting: data/rsna-small/images/26252/1593395169.png
#  extracting: data/rsna-small/images/32952/92079551.png
#  extracting: data/rsna-small/images/32952/424014460.png
#  extracting: data/rsna-small/images/32952/1225978295.png
#  extracting: data/rsna-small/images/32952/940726050.png
#  extracting: data/rsna-small/images/32952/273022568.png
#  extracting: data/rsna-small/images/32952/1009199062.png
#  extracting: data/rsna-small/images/19863/830473458.png
#  extracting: data/rsna-small/images/19863/1532044014.png
#  extracting: data/rsna-small/images/19863/20397031.png
#  extracting: data/rsna-small/images/19863/1495263968.png
#  extracting: data/rsna-small/images/19863/1486931097.png
#  extracting: data/rsna-small/images/60816/2110727014.png
#  extracting: data/rsna-small/images/60816/406126190.png
#  extracting: data/rsna-small/images/60816/2131843563.png
#  extracting: data/rsna-small/images/60816/794225784.png
#  extracting: data/rsna-small/images/19814/1615499816.png
#  extracting: data/rsna-small/images/19814/929646005.png
#  extracting: data/rsna-small/images/19814/670807206.png
#  extracting: data/rsna-small/images/19814/467373143.png
#  extracting: data/rsna-small/images/7059/1509102312.png
#  extracting: data/rsna-small/images/7059/1991581110.png
#  extracting: data/rsna-small/images/7059/534848897.png
#  extracting: data/rsna-small/images/7059/773798732.png
#  extracting: data/rsna-small/images/7059/576577906.png
#  extracting: data/rsna-small/images/7059/214147419.png
#  extracting: data/rsna-small/images/7059/1659701010.png
#  extracting: data/rsna-small/images/32591/2113316216.png
#  extracting: data/rsna-small/images/32591/1663808733.png
#  extracting: data/rsna-small/images/32591/1333160047.png
#  extracting: data/rsna-small/images/32591/1244450588.png
#  extracting: data/rsna-small/images/15281/1217109395.png
#  extracting: data/rsna-small/images/15281/1701106163.png
#  extracting: data/rsna-small/images/15281/1691130627.png
#  extracting: data/rsna-small/images/15281/376290448.png
#  extracting: data/rsna-small/images/15281/968576820.png
#  extracting: data/rsna-small/images/9036/512977389.png
#  extracting: data/rsna-small/images/9036/391968758.png
#  extracting: data/rsna-small/images/9036/1449540184.png
#  extracting: data/rsna-small/images/9036/791453915.png
#  extracting: data/rsna-small/images/19534/404289746.png
#  extracting: data/rsna-small/images/19534/2131778426.png
#  extracting: data/rsna-small/images/19534/997635930.png
#  extracting: data/rsna-small/images/19534/1615726237.png
#  extracting: data/rsna-small/images/57739/1734653062.png
#  extracting: data/rsna-small/images/57739/2010526907.png
#  extracting: data/rsna-small/images/57739/264518557.png
#  extracting: data/rsna-small/images/57739/377918057.png
#  extracting: data/rsna-small/images/57739/841853697.png
#  extracting: data/rsna-small/images/57739/738031985.png
#  extracting: data/rsna-small/images/5660/2106948712.png
#  extracting: data/rsna-small/images/5660/1284645157.png
#  extracting: data/rsna-small/images/5660/1798722912.png
#  extracting: data/rsna-small/images/5660/1135821513.png
#  extracting: data/rsna-small/images/32472/1134585098.png
#  extracting: data/rsna-small/images/32472/1533199704.png
#  extracting: data/rsna-small/images/32472/137964000.png
#  extracting: data/rsna-small/images/32472/1499774177.png
#  extracting: data/rsna-small/images/32472/903499222.png
#  extracting: data/rsna-small/images/32472/183781004.png
#  extracting: data/rsna-small/images/32472/415667305.png
#  extracting: data/rsna-small/images/19919/604538909.png
#  extracting: data/rsna-small/images/19919/1954464048.png
#  extracting: data/rsna-small/images/19919/200906308.png
#  extracting: data/rsna-small/images/19919/1502102864.png
#  extracting: data/rsna-small/images/19919/1413842125.png
#  extracting: data/rsna-small/images/16249/71091269.png
#  extracting: data/rsna-small/images/16249/1313318609.png
#  extracting: data/rsna-small/images/16249/1084474740.png
#  extracting: data/rsna-small/images/16249/488848855.png
#  extracting: data/rsna-small/images/16249/28529658.png
#  extracting: data/rsna-small/images/31559/625967483.png
#  extracting: data/rsna-small/images/31559/860198575.png
#  extracting: data/rsna-small/images/31559/1096951130.png
#  extracting: data/rsna-small/images/31559/1351660428.png
#  extracting: data/rsna-small/images/31559/1094704920.png
#  extracting: data/rsna-small/images/2923/1607840657.png
#  extracting: data/rsna-small/images/2923/1354054125.png
#  extracting: data/rsna-small/images/2923/909374161.png
#  extracting: data/rsna-small/images/2923/370141925.png
#  extracting: data/rsna-small/images/31903/1607700288.png
#  extracting: data/rsna-small/images/31903/158437360.png
#  extracting: data/rsna-small/images/31903/266523396.png
#  extracting: data/rsna-small/images/31903/741709389.png
#  extracting: data/rsna-small/images/52363/818685026.png
#  extracting: data/rsna-small/images/52363/1275878005.png
#  extracting: data/rsna-small/images/52363/1155907434.png
#  extracting: data/rsna-small/images/52363/1173793528.png
#  extracting: data/rsna-small/images/52363/386891414.png
#  extracting: data/rsna-small/images/52363/1232229880.png
#  extracting: data/rsna-small/images/27860/1609415645.png
#  extracting: data/rsna-small/images/27860/1894064785.png
#  extracting: data/rsna-small/images/27860/516699168.png
#  extracting: data/rsna-small/images/27860/113870021.png
#  extracting: data/rsna-small/images/27860/1566978535.png
#  extracting: data/rsna-small/images/50977/141321530.png
#  extracting: data/rsna-small/images/50977/888610127.png
#  extracting: data/rsna-small/images/50977/347202443.png
#  extracting: data/rsna-small/images/50977/1357725920.png
#  extracting: data/rsna-small/images/50977/1006396820.png
#  extracting: data/rsna-small/images/50977/1799962228.png
#  extracting: data/rsna-small/images/50977/2130578853.png
#  extracting: data/rsna-small/images/23608/471010287.png
#  extracting: data/rsna-small/images/23608/243955895.png
#  extracting: data/rsna-small/images/23608/939842535.png
#  extracting: data/rsna-small/images/23608/891637304.png
#  extracting: data/rsna-small/images/792/1117051791.png
#  extracting: data/rsna-small/images/792/2016106872.png
#  extracting: data/rsna-small/images/792/267054126.png
#  extracting: data/rsna-small/images/792/823351648.png
#  extracting: data/rsna-small/images/61224/469096094.png
#  extracting: data/rsna-small/images/61224/1019504634.png
#  extracting: data/rsna-small/images/61224/1749223770.png
#  extracting: data/rsna-small/images/61224/906128264.png
#  extracting: data/rsna-small/images/2859/1952865991.png
#  extracting: data/rsna-small/images/2859/1136731809.png
#  extracting: data/rsna-small/images/2859/786599298.png
#  extracting: data/rsna-small/images/2859/1957547920.png
#  extracting: data/rsna-small/images/2859/188909909.png
#  extracting: data/rsna-small/images/2859/1747436445.png
#  extracting: data/rsna-small/images/63484/837569863.png
#  extracting: data/rsna-small/images/63484/848735925.png
#  extracting: data/rsna-small/images/63484/129470481.png
#  extracting: data/rsna-small/images/63484/804969827.png
#  extracting: data/rsna-small/images/63484/1047958367.png
#  extracting: data/rsna-small/images/12101/1458191564.png
#  extracting: data/rsna-small/images/12101/213257752.png
#  extracting: data/rsna-small/images/12101/1946856519.png
#  extracting: data/rsna-small/images/12101/1626640097.png
#  extracting: data/rsna-small/images/12101/1873927169.png
# ...
#  extracting: data/rsna-small/images/65222/111055050.png
#  extracting: data/rsna-small/images/65222/1581943313.png
#  extracting: data/rsna-small/images/65222/749095883.png
#  extracting: data/rsna-small/images/65222/1559227517.png
#  extracting: data/rsna-small/images/65222/358676381.png
#    creating: data/rsna-small/images/4331/
#  extracting: data/rsna-small/images/4331/1709980032.png
#  extracting: data/rsna-small/images/4331/437851444.png
#  extracting: data/rsna-small/images/4331/66568061.png
#  extracting: data/rsna-small/images/4331/1572395797.png
#  extracting: data/rsna-small/images/4331/2128032346.png
#    creating: data/rsna-small/images/16170/
#  extracting: data/rsna-small/images/16170/665281000.png
#  extracting: data/rsna-small/images/16170/1288701276.png
#  extracting: data/rsna-small/images/16170/266249511.png
#  extracting: data/rsna-small/images/16170/570554298.png
#  extracting: data/rsna-small/images/16170/1440387646.png
#  extracting: data/rsna-small/images/16170/14940303.png
#    creating: data/rsna-small/images/23866/
#  extracting: data/rsna-small/images/23866/305848135.png
#  extracting: data/rsna-small/images/23866/1987755517.png
#  extracting: data/rsna-small/images/23866/326273633.png
#  extracting: data/rsna-small/images/23866/1068934180.png
#    creating: data/rsna-small/images/54451/
#  extracting: data/rsna-small/images/54451/2100031713.png
#  extracting: data/rsna-small/images/54451/1840488285.png
#  extracting: data/rsna-small/images/54451/49397325.png
#  extracting: data/rsna-small/images/54451/2115513291.png
#    creating: data/rsna-small/images/56365/
#  extracting: data/rsna-small/images/56365/648674563.png
#  extracting: data/rsna-small/images/56365/1599928420.png
#  extracting: data/rsna-small/images/56365/1925811792.png
#  extracting: data/rsna-small/images/56365/1925488337.png
#  extracting: data/rsna-small/images/56365/1720593799.png
#  extracting: data/rsna-small/images/56365/872991729.png
#    creating: data/rsna-small/images/8847/
#  extracting: data/rsna-small/images/8847/115087515.png
#  extracting: data/rsna-small/images/8847/564614495.png
#  extracting: data/rsna-small/images/8847/1449357372.png
#  extracting: data/rsna-small/images/8847/946680818.png
#    creating: data/rsna-small/images/6952/
#  extracting: data/rsna-small/images/6952/519361712.png
#  extracting: data/rsna-small/images/6952/1735250615.png
#  extracting: data/rsna-small/images/6952/280647977.png
#  extracting: data/rsna-small/images/6952/538874962.png
#    creating: data/rsna-small/images/29782/
#  extracting: data/rsna-small/images/29782/1052881794.png
#  extracting: data/rsna-small/images/29782/2039612198.png
#  extracting: data/rsna-small/images/29782/310750418.png
#  extracting: data/rsna-small/images/29782/891153636.png
#  extracting: data/rsna-small/images/29782/2089194353.png
#    creating: data/rsna-small/images/54426/
#  extracting: data/rsna-small/images/54426/1775124210.png
#  extracting: data/rsna-small/images/54426/398433382.png
#  extracting: data/rsna-small/images/54426/1736599251.png
#  extracting: data/rsna-small/images/54426/222659860.png
#  extracting: data/rsna-small/images/54426/2039304873.png
#    creating: data/rsna-small/images/35905/
#  extracting: data/rsna-small/images/35905/1654657351.png
#  extracting: data/rsna-small/images/35905/831959694.png
#  extracting: data/rsna-small/images/35905/909194132.png
#  extracting: data/rsna-small/images/35905/271868180.png
#  extracting: data/rsna-small/images/35905/1079952134.png
#    creating: data/rsna-small/images/24628/
#  extracting: data/rsna-small/images/24628/830108123.png
#  extracting: data/rsna-small/images/24628/1007266558.png
#  extracting: data/rsna-small/images/24628/638913789.png
#  extracting: data/rsna-small/images/24628/1253880828.png
#    creating: data/rsna-small/images/41563/
#  extracting: data/rsna-small/images/41563/1170510772.png
#  extracting: data/rsna-small/images/41563/966127130.png
#  extracting: data/rsna-small/images/41563/1242309259.png
#  extracting: data/rsna-small/images/41563/376245477.png
#    creating: data/rsna-small/images/20840/
#  extracting: data/rsna-small/images/20840/1909467256.png
#  extracting: data/rsna-small/images/20840/1822937251.png
#  extracting: data/rsna-small/images/20840/869465692.png
#  extracting: data/rsna-small/images/20840/581529691.png
#  extracting: data/rsna-small/images/20840/186542720.png
#  extracting: data/rsna-small/images/20840/1444491611.png
#  extracting: data/rsna-small/images/20840/1216743133.png
#  extracting: data/rsna-small/images/20840/1638995820.png
#    creating: data/rsna-small/images/15156/
#  extracting: data/rsna-small/images/15156/578409314.png
#  extracting: data/rsna-small/images/15156/383535661.png
#  extracting: data/rsna-small/images/15156/509417747.png
#  extracting: data/rsna-small/images/15156/1352006898.png
#    creating: data/rsna-small/images/5423/
#  extracting: data/rsna-small/images/5423/104808478.png
#  extracting: data/rsna-small/images/5423/1868642183.png
#  extracting: data/rsna-small/images/5423/391169011.png
#  extracting: data/rsna-small/images/5423/1998597931.png
#    creating: data/rsna-small/images/19700/
#  extracting: data/rsna-small/images/19700/1820353093.png
#  extracting: data/rsna-small/images/19700/1309669876.png
#  extracting: data/rsna-small/images/19700/786537821.png
#  extracting: data/rsna-small/images/19700/1769331096.png
#    creating: data/rsna-small/images/22359/
#  extracting: data/rsna-small/images/22359/1894222824.png
#  extracting: data/rsna-small/images/22359/1762445904.png
#  extracting: data/rsna-small/images/22359/907140921.png
#  extracting: data/rsna-small/images/22359/836548015.png
#  extracting: data/rsna-small/images/22359/1364844215.png
#    creating: data/rsna-small/images/47186/
#  extracting: data/rsna-small/images/47186/465289510.png
#  extracting: data/rsna-small/images/47186/2132719815.png
#  extracting: data/rsna-small/images/47186/720794351.png
#  extracting: data/rsna-small/images/47186/1754437049.png
#  extracting: data/rsna-small/images/47186/1307131253.png
#  extracting: data/rsna-small/images/47186/1418290508.png
#    creating: data/rsna-small/images/9396/
#  extracting: data/rsna-small/images/9396/61799379.png
#  extracting: data/rsna-small/images/9396/1854003743.png
#  extracting: data/rsna-small/images/9396/300142861.png
#  extracting: data/rsna-small/images/9396/1991055987.png
#  extracting: data/rsna-small/images/9396/278591661.png
#    creating: data/rsna-small/images/38836/
#  extracting: data/rsna-small/images/38836/2025869675.png
#  extracting: data/rsna-small/images/38836/1317875885.png
#  extracting: data/rsna-small/images/38836/1468917926.png
#  extracting: data/rsna-small/images/38836/748391165.png
#  extracting: data/rsna-small/images/38836/1903697630.png
#  extracting: data/rsna-small/images/38836/1402407800.png
#  extracting: data/rsna-small/images/38836/2115081107.png
#    creating: data/rsna-small/images/26185/
#  extracting: data/rsna-small/images/26185/1864113759.png
#  extracting: data/rsna-small/images/26185/1189325692.png
#  extracting: data/rsna-small/images/26185/1971298674.png
#  extracting: data/rsna-small/images/26185/972252340.png
#    creating: data/rsna-small/images/22223/
#  extracting: data/rsna-small/images/22223/1038633621.png
#  extracting: data/rsna-small/images/22223/1737279740.png
#  extracting: data/rsna-small/images/22223/1375170425.png
#  extracting: data/rsna-small/images/22223/1388838926.png
#  extracting: data/rsna-small/images/22223/588792398.png
#  extracting: data/rsna-small/images/22223/1113003215.png
#    creating: data/rsna-small/images/24752/
#  extracting: data/rsna-small/images/24752/335276847.png
#  extracting: data/rsna-small/images/24752/779760980.png
#  extracting: data/rsna-small/images/24752/539836420.png
#  extracting: data/rsna-small/images/24752/55361095.png
#  extracting: data/rsna-small/images/24752/97532695.png
#  extracting: data/rsna-small/images/24752/1546041515.png
#    creating: data/rsna-small/images/1688/
#  extracting: data/rsna-small/images/1688/1695802156.png
#  extracting: data/rsna-small/images/1688/319228472.png
#  extracting: data/rsna-small/images/1688/1101023033.png
#  extracting: data/rsna-small/images/1688/550590619.png
#  extracting: data/rsna-small/images/1688/862827811.png
#    creating: data/rsna-small/images/36954/
#  extracting: data/rsna-small/images/36954/1013315088.png
#  extracting: data/rsna-small/images/36954/1096296603.png
#  extracting: data/rsna-small/images/36954/318592356.png
#  extracting: data/rsna-small/images/36954/719270916.png
#    creating: data/rsna-small/images/38841/
#  extracting: data/rsna-small/images/38841/1766160052.png
#  extracting: data/rsna-small/images/38841/235747395.png
#  extracting: data/rsna-small/images/38841/1466182506.png
#  extracting: data/rsna-small/images/38841/195213777.png
#  extracting: data/rsna-small/images/38841/1523064281.png
#    creating: data/rsna-small/images/56658/
#  extracting: data/rsna-small/images/56658/806946410.png
#  extracting: data/rsna-small/images/56658/402536310.png
#  extracting: data/rsna-small/images/56658/712856730.png
#  extracting: data/rsna-small/images/56658/1510335319.png
#  extracting: data/rsna-small/images/56658/868474213.png
#  extracting: data/rsna-small/images/56658/6452059.png
#    creating: data/rsna-small/images/31227/
#  extracting: data/rsna-small/images/31227/625778439.png
#  extracting: data/rsna-small/images/31227/1892895614.png
#  extracting: data/rsna-small/images/31227/1043674531.png
#  extracting: data/rsna-small/images/31227/1655165391.png
#  extracting: data/rsna-small/images/31227/1662566032.png
#  extracting: data/rsna-small/images/31227/1809794521.png
#    creating: data/rsna-small/images/39634/
#  extracting: data/rsna-small/images/39634/7126520.png
#  extracting: data/rsna-small/images/39634/468688142.png
#  extracting: data/rsna-small/images/39634/691755887.png
#  extracting: data/rsna-small/images/39634/1398103204.png
#    creating: data/rsna-small/images/37721/
#  extracting: data/rsna-small/images/37721/642125576.png
#  extracting: data/rsna-small/images/37721/1460391550.png
#  extracting: data/rsna-small/images/37721/437805951.png
#  extracting: data/rsna-small/images/37721/448341017.png
#  extracting: data/rsna-small/images/37721/854373341.png
#  extracting: data/rsna-small/images/37721/137327344.png
#    creating: data/rsna-small/images/21738/
#  extracting: data/rsna-small/images/21738/1634217451.png
#  extracting: data/rsna-small/images/21738/1723511719.png
#  extracting: data/rsna-small/images/21738/976572825.png
#  extracting: data/rsna-small/images/21738/1167879870.png
#    creating: data/rsna-small/images/12608/
#  extracting: data/rsna-small/images/12608/208024474.png
#  extracting: data/rsna-small/images/12608/677186927.png
#  extracting: data/rsna-small/images/12608/1366158176.png
#  extracting: data/rsna-small/images/12608/477106886.png
#  extracting: data/rsna-small/images/12608/1519686055.png
#  extracting: data/rsna-small/images/12608/285313482.png
#    creating: data/rsna-small/images/16860/
#  extracting: data/rsna-small/images/16860/1083363186.png
#  extracting: data/rsna-small/images/16860/1653669509.png
#  extracting: data/rsna-small/images/16860/1601839348.png
#  extracting: data/rsna-small/images/16860/1036750820.png
#  extracting: data/rsna-small/images/16860/1410646839.png
#  extracting: data/rsna-small/images/16860/1202428057.png
#    creating: data/rsna-small/images/27344/
#  extracting: data/rsna-small/images/27344/2060786840.png
#  extracting: data/rsna-small/images/27344/1481766531.png
#  extracting: data/rsna-small/images/27344/1938505294.png
#  extracting: data/rsna-small/images/27344/1661167822.png
#  extracting: data/rsna-small/images/27344/207495802.png
#    creating: data/rsna-small/images/44509/
#  extracting: data/rsna-small/images/44509/2055973298.png
#  extracting: data/rsna-small/images/44509/1986484694.png
#  extracting: data/rsna-small/images/44509/952008705.png
#  extracting: data/rsna-small/images/44509/277290392.png
#  extracting: data/rsna-small/images/44509/574566410.png
#    creating: data/rsna-small/images/58637/
#  extracting: data/rsna-small/images/58637/1140023809.png
#  extracting: data/rsna-small/images/58637/894696175.png
#  extracting: data/rsna-small/images/58637/856678931.png
#  extracting: data/rsna-small/images/58637/3343518.png
#    creating: data/rsna-small/images/29226/
#  extracting: data/rsna-small/images/29226/1561209997.png
#  extracting: data/rsna-small/images/29226/609097651.png
#  extracting: data/rsna-small/images/29226/5576040.png
#  extracting: data/rsna-small/images/29226/724225181.png
#    creating: data/rsna-small/images/17252/
#  extracting: data/rsna-small/images/17252/136822960.png
#  extracting: data/rsna-small/images/17252/149250488.png
#  extracting: data/rsna-small/images/17252/68060005.png
#  extracting: data/rsna-small/images/17252/554407647.png
#    creating: data/rsna-small/images/47455/
#  extracting: data/rsna-small/images/47455/1966021463.png
#  extracting: data/rsna-small/images/47455/1017032466.png
#  extracting: data/rsna-small/images/47455/1107790262.png
#  extracting: data/rsna-small/images/47455/607377238.png
#    creating: data/rsna-small/images/11723/
#  extracting: data/rsna-small/images/11723/205026172.png
#  extracting: data/rsna-small/images/11723/41321230.png
#  extracting: data/rsna-small/images/11723/1144274527.png
#  extracting: data/rsna-small/images/11723/970904871.png
#  extracting: data/rsna-small/images/11723/622500947.png
#  extracting: data/rsna-small/images/11723/2099359072.png
#    creating: data/rsna-small/images/51982/
#  extracting: data/rsna-small/images/51982/760601666.png
#  extracting: data/rsna-small/images/51982/1368481694.png
#  extracting: data/rsna-small/images/51982/221626226.png
#  extracting: data/rsna-small/images/51982/1380062569.png
#  extracting: data/rsna-small/images/51982/224980281.png
#    creating: data/rsna-small/images/32201/
#  extracting: data/rsna-small/images/32201/1401039508.png
#  extracting: data/rsna-small/images/32201/1775199518.png
#  extracting: data/rsna-small/images/32201/1249035387.png
#  extracting: data/rsna-small/images/32201/1120175097.png
#    creating: data/rsna-small/images/62926/
#  extracting: data/rsna-small/images/62926/459358867.png
#  extracting: data/rsna-small/images/62926/417234241.png
#  extracting: data/rsna-small/images/62926/200669454.png
#  extracting: data/rsna-small/images/62926/1016990185.png
#  extracting: data/rsna-small/images/62926/861261225.png
#    creating: data/rsna-small/images/64199/
#  extracting: data/rsna-small/images/64199/251713756.png
#  extracting: data/rsna-small/images/64199/762564227.png
#  extracting: data/rsna-small/images/64199/2056740866.png
#  extracting: data/rsna-small/images/64199/397020447.png
#    creating: data/rsna-small/images/59152/
#  extracting: data/rsna-small/images/59152/2039108158.png
#  extracting: data/rsna-small/images/59152/1993388187.png
#  extracting: data/rsna-small/images/59152/1455515450.png
#  extracting: data/rsna-small/images/59152/1237061311.png
#  extracting: data/rsna-small/images/59152/1181374608.png
#    creating: data/rsna-small/images/22664/
#  extracting: data/rsna-small/images/22664/82026330.png
#  extracting: data/rsna-small/images/22664/1340373550.png
#  extracting: data/rsna-small/images/22664/2086364819.png
#  extracting: data/rsna-small/images/22664/1902471620.png
#    creating: data/rsna-small/images/30862/
#  extracting: data/rsna-small/images/30862/555180313.png
#  extracting: data/rsna-small/images/30862/2008621522.png
#  extracting: data/rsna-small/images/30862/828632392.png
#  extracting: data/rsna-small/images/30862/1809411926.png
#    creating: data/rsna-small/images/15846/
#  extracting: data/rsna-small/images/15846/192940406.png
#  extracting: data/rsna-small/images/15846/1340714452.png
#  extracting: data/rsna-small/images/15846/314932821.png
#  extracting: data/rsna-small/images/15846/2059790301.png

# %%
DATA_DIR = './data/rsna-small'
CSV_FILE = os.path.join(DATA_DIR, 'meta.csv')
IMAGE_SIZE = (128, 96)
NUM_CLASSES = 4

# %% [markdown]
# Let's check the meta information of the dataset.

# %%
df_meta = pd.read_csv(CSV_FILE)
df_meta.head()
# Out:
#      image_id laterality view   age  cancer  implant density  machine_id  \
# 0  1967300488          L  MLO  60.0       0        0       C         216
# 1  2142944869          L   CC  60.0       0        0       C         216
# 2   850559196          R  MLO  60.0       0        0       C         216
# 3  1350492010          R   CC  60.0       0        0       C         216
# 4   102733848          L   CC  51.0       0        0       C          93
#
#    study_id     split
# 0     10038  training
# 1     10038  training
# 2     10038  training
# 3     10038  training
# 4     10042  training

# %% [markdown]
# Let's visualise some random samples from each density class. You can run this cell repeatedly to see different samples.

# %%
N_PER_CLASS = 4  # Number of images per class to display
CLASSES_DISPLAY = ["A", "B", "C", "D"] # Breast density classes for display

df_meta["img_path"] = [
    os.path.join(
        DATA_DIR, "images",
        str(df_meta.study_id.values[i]),
        str(df_meta.image_id.values[i]) + ".png"
    )
    for i in range(len(df_meta))
]

# display sample images from each class
fig, axes = plt.subplots(len(CLASSES_DISPLAY), N_PER_CLASS, figsize=(1.9 * N_PER_CLASS, 2.2 * len(CLASSES_DISPLAY)))
if N_PER_CLASS == 1: # In case of single column, expand dims
    axes = np.expand_dims(axes, axis=1)

for r, cls in enumerate(CLASSES_DISPLAY):
    sub = df_meta[df_meta["density"] == cls]
    k = min(N_PER_CLASS, len(sub))
    sample_idx = np.random.choice(len(sub), size=k, replace=False)
    samples = sub.iloc[sample_idx]
    for c in range(N_PER_CLASS):
        ax = axes[r, c]
        ax.axis("off")
        if c < k:
            img = imread(samples.iloc[c]["img_path"])
            ax.imshow(img, cmap="gray")
            ax.set_title(f"Density {cls}", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Part A**: Choose a sensible data augmentation pipeline within the `MammoDataset` class.

# %% [markdown]
# We provide a custom [PyTorch Dataset](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html) that manages the RSNA-SMBC dataset.
#
# **TASK:** Implement data augmentation for mammography images. You can use the `torchvision.transforms.v2` module to select a sensible set of photometric and geometric transformations. Report your choices in the coursework report.

# %% [markdown]
# 1. Let's check if the dataset is balanced or not.

# %%
# occurrences of each density class
counts = df_meta['density'].value_counts().reindex(CLASSES_DISPLAY)

rose_pastel = ["#FFD1DC", "#FFB7C5", "#F898A4", "#E75480"]

plt.figure(figsize=(8, 5))
sns.barplot(x=counts.index, y=counts.values, hue=counts.index, palette=rose_pastel, legend=False)
plt.xlabel('Breast Density Class', fontsize=12)
plt.ylabel('Number of Images', fontsize=12)
plt.title('Distribution of Breast Density Classes (RSNA-Small)', fontsize=14)

for i, v in enumerate(counts.values):
    plt.text(i, v + 100, str(v), ha='center', fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
class MammoDataset(Dataset):
    def __init__(self, data, image_size, image_normalization, augmentation = False, cache_size = 0):
        self.image_normalization = image_normalization
        self.do_augment = augmentation

        # photometric
        self.photometric_augment = T.Compose([
            T.RandomAdjustSharpness(sharpness_factor=2, p=0.3),
            T.RandomAutocontrast(p=0.3),
            T.GaussianBlur(kernel_size=3, sigma=(0.1, 1.5)),
        ])

        # geometric
        self.geometric_augment = T.Compose([
            T.RandomHorizontalFlip(p=0.5),
            T.RandomVerticalFlip(p=0.2),
            T.RandomAffine(degrees=15, translate=(0.05, 0.05), scale=(0.9, 1.1)),
            T.RandomResizedCrop(size=image_size, scale=(0.8, 1.0), ratio=(0.9, 1.1), antialias=True),
        ])
  
        # load metadata into numpy arrays for faster access
        self.img_paths = data.img_path.to_numpy()
        self.study_ids = data.study_id.to_numpy()
        self.image_ids = data.image_id.to_numpy()
        self.labels = data.labels.to_numpy()

        # cache for preprocessed images to speed up training after the first epoch
        self.cache = None
        self.use_cache = cache_size > 0
        if self.use_cache:
            self.cache = SharedCache(
                size_limit_gib=cache_size,
                dataset_len=self.labels.shape[0],
                data_dims=(1, image_size[0], image_size[1]),
                dtype=torch.float32,
            )

    def preprocess(self, image):
        # breast segmentation using connected components
        image_norm = image - np.min(image)
        image_norm = image_norm / np.max(image_norm)
        thresh = cv2.threshold(img_as_ubyte(image_norm), 5, 255, cv2.THRESH_BINARY)[1]
        nb_components, output, stats, _ = cv2.connectedComponentsWithStats(thresh, connectivity=4)

        # Find the largest non background component.
        max_label, _ = max(
            [(i, stats[i, cv2.CC_STAT_AREA]) for i in range(1, nb_components)],
            key=lambda x: x[1],
        )
        mask = output == max_label
        image[mask == 0] = 0
                
        return image

    def __len__(self):
        return self.labels.shape[0]

    def __getitem__(self, index):
        image = None
        if self.use_cache:
            image = self.cache.get_slot(index)
        
        if image is None:
            img_path = self.img_paths[index]
            image = imread(img_path).astype(np.float32)
            image = self.preprocess(image)
            image = torch.from_numpy(image).unsqueeze(0)            
            
            if self.use_cache:
                self.cache.set_slot(index, image, allow_overwrite=True)

        # normalize intensities to range [0,1]
        image = image / self.image_normalization

        if self.do_augment:
            image = self.photometric_augment(image)
            image = self.geometric_augment(image)

        # convert to 3-channel image to be compatible with pretrained models
        image = image.repeat(3, 1, 1)

        return {'image': image, 'label': self.labels[index], 'study_id': self.study_ids[index], 'image_id': self.image_ids[index]}
    
    def get_labels(self):
        return self.labels

# %% [markdown]
# We use a [LightningDataModule](https://lightning.ai/docs/pytorch/stable/data/datamodule.html) for preparing the RSNA-SMBC dataset and its training, validation and test splits. No changes required here but make sure that you understand what is happening within this module.

# %%
class MammoDataModule(pl.LightningDataModule):
    def __init__(self, data_dir, csv_file, image_size, batch_size, num_workers):
        super().__init__()
        self.data_dir = data_dir
        self.image_size = image_size
        self.batch_size = batch_size
        self.num_workers = num_workers

        # load metadata
        self.data = pd.read_csv(csv_file)

        # construct image paths from metadata
        self.data['img_path'] = [os.path.join(self.data_dir, 'images', str(self.data.study_id.values[idx]), str(self.data.image_id.values[idx]) + '.png') for idx in range(0, len(self.data))]

        # Define image labels based on breast density classes
        self.data['labels'] = self.data['density']
        self.data.loc[self.data['labels'] == 'A', 'labels'] = 0
        self.data.loc[self.data['labels'] == 'B', 'labels'] = 1
        self.data.loc[self.data['labels'] == 'C', 'labels'] = 2
        self.data.loc[self.data['labels'] == 'D', 'labels'] = 3

        # Use pre-defined splits to separate data into train, val and testing
        self.train_data = self.data[self.data['split'] == 'training']
        self.val_data = self.data[self.data['split'] == 'validation']
        self.test_data = self.data[self.data['split'] == 'test']

        # create dataset objects for each split
        self.train_set = MammoDataset(self.
                                      , self.image_size, image_normalization=65535.0, augmentation=True, cache_size=2)
        self.val_set = MammoDataset(self.val_data, self.image_size, image_normalization=65535.0, augmentation=False, cache_size=0.5)
        self.test_set = MammoDataset(self.test_data, self.image_size, image_normalization=65535.0, augmentation=False)

        # print dataset statistics
        train_labels = self.train_set.get_labels()
        train_class_count = np.array([len(np.where(train_labels == t)[0]) for t in np.unique(train_labels)])

        val_labels = self.val_set.get_labels()        
        val_class_count = np.array([len(np.where(val_labels == t)[0]) for t in np.unique(val_labels)])

        test_labels = self.test_set.get_labels()        
        test_class_count = np.array([len(np.where(test_labels == t)[0]) for t in np.unique(test_labels)])

        print('samples (train): ',len(self.train_set))
        print('samples (val):   ',len(self.val_set))
        print('samples (test):  ',len(self.test_set))
        print('class counts (train): ', train_class_count)
        print('class counts (val):   ', val_class_count)
        print('class counts (test):  ', test_class_count)
        print('class % (train): ', np.array([f"{x:.2f}" for x in np.array(train_class_count/len(train_labels)*100.0)]))
        print('class % (val):   ', np.array([f"{x:.2f}" for x in np.array(val_class_count/len(val_labels)*100.0)]))
        print('class % (test):  ', np.array([f"{x:.2f}" for x in np.array(test_class_count/len(test_labels)*100.0)]))

    def train_dataloader(self):
        # we use ImbalancedDatasetSampler to handle class imbalance in the training set
        return DataLoader(dataset=self.tr
                          
                          ain_set, batch_size=self.batch_size, sampler=ImbalancedDatasetSampler(self.train_set), num_workers=self.num_workers, pin_memory=True)

    def val_dataloader(self):
        return DataLoader(dataset=self.val_set, batch_size=self.batch_size, shuffle=False, num_workers=self.num_workers)

    def test_dataloader(self):
        return DataLoader(dataset=self.test_set, batch_size=self.batch_size, shuffle=False, num_workers=self.num_workers)

# %% [markdown]
# ## **Part B**: Implement a sensible model for image classification within the `MammoNet` class.

# %% [markdown]
# We use a [LightningModule](https://lightning.ai/docs/pytorch/stable/common/lightning_module.html) for implementing the model and its training and testing steps.
#
# **TASK:** Implement and try out different models suitable for the breast density prediction problem. Check out the `torchvision.models` module. Report your choices in the coursework report.

# %%
class MammoNet(pl.LightningModule):
    def __init__(self, num_classes, model_type='resnet18', learning_rate=0.0001):
        super().__init__()
        self.num_classes = num_classes
        self.lr = learning_rate
        self.model_type = model_type

        if model_type == 'resnet18':
                    self.model = torchvision.models.resnet18(weights='IMAGENET1K_V1')
                    num_ftrs = self.model.fc.in_features
                    self.model.fc = nn.Linear(num_ftrs, num_classes)
            
        elif model_type == 'densenet121':
            self.model = torchvision.models.densenet121(weights='IMAGENET1K_V1')
            num_ftrs = self.model.classifier.in_features
            self.model.classifier = nn.Linear(num_ftrs, num_classes)

        elif model_type == '2MLPmodel':
            input_dim = IMAGE_SIZE[0] * IMAGE_SIZE[1] * 3
            self.model = nn.Sequential(
                nn.Flatten(), # replace the x.view() in the forward
                nn.Linear(input_dim, 512),
                nn.ReLU(),
                nn.Linear(512, self.num_classes)
            )
    def forward(self, x):
        return self.model(x)


    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        return optimizer

    def process_batch(self, batch):
        img, lab = batch['image'], batch['label']
        out = self.forward(img)
        prd = torch.softmax(out, dim=1)
        loss = F.cross_entropy(out, lab)
        return loss, prd, lab

    def on_train_epoch_start(self):
        self.train_preds = []
        self.train_trgts = []

    def training_step(self, batch, batch_idx):
        loss, prd, lab = self.process_batch(batch)
        self.log('train_loss', loss, batch_size=lab.shape[0])
        self.train_preds.append(prd.detach().cpu())
        self.train_trgts.append(lab.detach().cpu())
        if batch_idx == 0:
            images = batch['image'][0:4, ...].detach().cpu()
            grid = torchvision.utils.make_grid(images, nrow=2, normalize=True)
            self.logger.experiment.add_image('images', grid, self.global_step)
        return loss

    def on_train_epoch_end(self):
        self.train_preds = torch.cat(self.train_preds, dim=0)
        self.train_trgts = torch.cat(self.train_trgts, dim=0)
        auc = auroc(self.train_preds, self.train_trgts, num_classes=self.num_classes, average='macro', task='multiclass')
        self.log('train_auc', auc)
        self.train_preds = []
        self.train_trgts = []

    def on_validation_epoch_start(self):
        self.val_preds = []
        self.val_trgts = []

    def validation_step(self, batch, batch_idx):
        loss, prd, lab = self.process_batch(batch)
        self.log('val_loss', loss, batch_size=lab.shape[0])
        self.val_preds.append(prd.detach().cpu())
        self.val_trgts.append(lab.detach().cpu())

    def on_validation_epoch_end(self):
        self.val_preds = torch.cat(self.val_preds, dim=0)
        self.val_trgts = torch.cat(self.val_trgts, dim=0)
        auc = auroc(self.val_preds, self.val_trgts, num_classes=self.num_classes, average='macro', task='multiclass')
        self.log('val_auc', auc)
        self.val_preds = []
        self.val_trgts = []

    def on_test_epoch_start(self):
        self.test_preds = []
        self.test_trgts = []
        self.test_study_ids = []
        self.test_image_ids = []

    def test_step(self, batch, batch_idx):
        loss, prd, lab = self.process_batch(batch)
        self.log('test_loss', loss, batch_size=lab.shape[0])
        self.test_preds.append(prd.detach().cpu())
        self.test_trgts.append(lab.detach().cpu())        
        self.test_study_ids.append(batch['study_id'].detach().cpu())
        self.test_image_ids.append(batch['image_id'].detach().cpu())

    def on_test_epoch_end(self):
        self.test_preds = torch.cat(self.test_preds, dim=0)
        self.test_trgts = torch.cat(self.test_trgts, dim=0)
        auc = auroc(self.test_preds, self.test_trgts, num_classes=self.num_classes, average='macro', task='multiclass')
        self.log('test_auc', auc)

# %% [markdown]
# ### Training

# %% [markdown]
# We use the PyTorch Lightning [Trainer](https://lightning.ai/docs/pytorch/stable/common/trainer.html) for easy training and testing. You may need to adjust the number of epochs, but otherwise you should be able to just run the cell and wait for the training to complete.
#
# **TASK:** Adjust the number of epochs if needed. Report any observations about the training in your coursework report (you may want to check training and validation curves via Tensorboard).

# %%
import os
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint, TQDMProgressBar

model_types = ['resnet18', 'densenet121', '2MLPmodel']
all_trainers = {}
all_models = {}

data = MammoDataModule(data_dir=DATA_DIR, csv_file=CSV_FILE, image_size=IMAGE_SIZE, batch_size=128, num_workers=2) 

for model_type in model_types:
    print(f"\n>>> Training Model: {model_type}")
    pl.seed_everything(42, workers=True)
    model = MammoNet(num_classes=NUM_CLASSES, model_type=model_type, learning_rate=0.001)

    output_base = './output/'
    output_name = f'mammo-net-{model_type}'
    output_dir = os.path.join(output_base, output_name)

    checkpoint_callback = ModelCheckpoint(
        monitor="val_auc",
        dirpath=output_dir,
        filename=f"best-{model_type}-" + "{epoch:02d}-{val_auc:.2f}",
        mode="max",
        save_top_k=1
    )

    trainer = pl.Trainer(
        max_epochs=10,
        accelerator='auto',
        devices=1,
        log_every_n_steps=5,
        logger=TensorBoardLogger(save_dir='./output/', name=output_name),
        callbacks=[checkpoint_callback, TQDMProgressBar(refresh_rate=10)],
    )

    trainer.fit(model=model, datamodule=data)
    
    all_trainers[model_type] = trainer
    all_models[model_type] = model
# Out:
# Dataset size (1.0 GiB) fits in cache limit (2 GiB). Allocating space to cache all 21204 samples.
# Seed set to 42
# Dataset size (0.1 GiB) fits in cache limit (0.5 GiB). Allocating space to cache all 2368 samples.
# samples (train):  21204
# samples (val):    2368
# samples (test):   5865
# class counts (train):  [2224 9057 8856 1067]
# class counts (val):    [ 247 1034  938  149]
# class counts (test):   [ 628 2548 2368  321]
# class % (train):  ['10.49' '42.71' '41.77' '5.03']
# class % (val):    ['10.43' '43.67' '39.61' '6.29']
# class % (test):   ['10.71' '43.44' '40.38' '5.47']
#
# >>> Training Model: resnet18
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /vol/bitbucket/jc2425/cw1/myenv/lib/python3.12/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:881: Checkpoint directory /vol/bitbucket/jc2425/cw1/output/mammo-net-resnet18 exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type   ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ ResNet │ 11.2 M │ train │     0 │
# └───┴───────┴────────┴────────┴───────┴───────┘
# Trainable params: 11.2 M
# Non-trainable params: 0
# Total params: 11.2 M
# Total estimated model params size (MB): 44
# Modules in train mode: 68
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Seed set to 42
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /homes/jc2425/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# >>> Training Model: densenet121
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 111MB/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /vol/bitbucket/jc2425/cw1/myenv/lib/python3.12/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:881: Checkpoint directory /vol/bitbucket/jc2425/cw1/output/mammo-net-densenet121 exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type     ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ DenseNet │  7.0 M │ train │     0 │
# └───┴───────┴──────────┴────────┴───────┴───────┘
# Trainable params: 7.0 M
# Non-trainable params: 0
# Total params: 7.0 M
# Total estimated model params size (MB): 27
# Modules in train mode: 433
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Seed set to 42
# >>> Training Model: 2MLPmodel
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /vol/bitbucket/jc2425/cw1/myenv/lib/python3.12/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:881: Checkpoint directory /vol/bitbucket/jc2425/cw1/output/mammo-net-2MLPmodel exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ Sequential │ 18.9 M │ train │     0 │
# └───┴───────┴────────────┴────────┴───────┴───────┘
# Trainable params: 18.9 M
# Non-trainable params: 0
# Total params: 18.9 M
# Total estimated model params size (MB): 75
# Modules in train mode: 5
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.

# %% [markdown]
# ### Validation

# %% [markdown]
# Evaluate the trained model with the best checkpoint on the validation data and report the classification performance.
#
# **TASK:** You should report the validation performance and some information about the model checkpoint in the coursework report (at what epoch/iteration did you find the best checkpoint).

# %%
results_summary = []

for model_type in model_types:
    trainer = all_trainers[model_type]
    model = all_models[model_type]
    
    best_model_path = trainer.checkpoint_callback.best_model_path
    
    print(f"\n--- Evaluating Best {model_type} ---")
    val_results = trainer.validate(model=model, datamodule=data, ckpt_path=best_model_path)
    
    checkpoint = torch.load(best_model_path)
    best_epoch = checkpoint['epoch']
    
    results_summary.append({
        'Model': model_type,
        'Best Epoch': best_epoch,
        'Val AUC': val_results[0]['val_auc'],
        'Val Loss': val_results[0]['val_loss']
    })

# Comparison of results across models

df_results = pd.DataFrame(results_summary)
print("\n" + "="*40)
print("FINAL REPORT SUMMARY")
print(df_results)
print("="*40)
# Out:
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-resnet18/best-resnet18-epoch=08-val_auc=0.92.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-resnet18/best-resnet18-epoch=08-val_auc=0.92.ckpt
# --- Evaluating Best resnet18 ---
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_auc          │     0.917738676071167     │
# │         val_loss          │    0.6365287899971008     │
# └───────────────────────────┴───────────────────────────┘
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-densenet121/best-densenet121-epoch=01-val_auc=0.93.ckpt
# --- Evaluating Best densenet121 ---
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-densenet121/best-densenet121-epoch=01-val_auc=0.93.ckpt
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_auc          │    0.9300308227539062     │
# │         val_loss          │     0.596306562423706     │
# └───────────────────────────┴───────────────────────────┘
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-2MLPmodel/best-2MLPmodel-epoch=04-val_auc=0.82.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-2MLPmodel/best-2MLPmodel-epoch=04-val_auc=0.82.ckpt
# --- Evaluating Best 2MLPmodel ---
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_auc          │    0.8180335760116577     │
# │         val_loss          │    0.9367037415504456     │
# └───────────────────────────┴───────────────────────────┘
# ========================================
# FINAL REPORT SUMMARY
#          Model  Best Epoch   Val AUC  Val Loss
# 0     resnet18           8  0.917739  0.636529
# 1  densenet121           1  0.930031  0.596307
# 2    2MLPmodel           4  0.818034  0.936704
# ========================================

# %% [markdown]
# ### Testing

# %% [markdown]
# Evaluate the trained model with the best checkpoint on the test data and report the classification performance.
#
# **TASK:** You should report the test performance in the coursework report.

# %%
def save_predictions(model, output_fname):
    std_ids = [id.numpy() for sublist in model.test_study_ids for id in sublist]
    img_ids = [id.numpy() for sublist in model.test_image_ids for id in sublist]
    cols_names = ['class_' + str(i) for i in range(0, NUM_CLASSES)]
    df = pd.DataFrame(data=model.test_preds.numpy(), columns=cols_names)    
    df['target'] = model.test_trgts.numpy()
    df['study_id'] = std_ids
    df['image_id'] = img_ids
    df.to_csv(output_fname, index=False)

# %%
for model_type in model_types:
    trainer = all_trainers[model_type]
    model = all_models[model_type]
    best_path = trainer.checkpoint_callback.best_model_path
    output_dir = os.path.join('./output/', f'mammo-net-{model_type}')
    print(f"\n>>> Running Final Test for {model_type}")
    trainer.test(model=model, datamodule=data, ckpt_path=best_path)
    
    output_fname = os.path.join(output_dir, f'predictions_{model_type}.csv')
    save_predictions(model=model, output_fname=output_fname)
# Out:
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-resnet18/best-resnet18-epoch=08-val_auc=0.92.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-resnet18/best-resnet18-epoch=08-val_auc=0.92.ckpt
# >>> Running Final Test for resnet18
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_auc          │    0.9060407876968384     │
# │         test_loss         │    0.6573233604431152     │
# └───────────────────────────┴───────────────────────────┘
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-densenet121/best-densenet121-epoch=01-val_auc=0.93.ckpt
# >>> Running Final Test for densenet121
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-densenet121/best-densenet121-epoch=01-val_auc=0.93.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_auc          │    0.9197657108306885     │
# │         test_loss         │    0.6089603304862976     │
# └───────────────────────────┴───────────────────────────┘
# Restoring states from the checkpoint path at /vol/bitbucket/jc2425/cw1/output/mammo-net-2MLPmodel/best-2MLPmodel-epoch=04-val_auc=0.82.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /vol/bitbucket/jc2425/cw1/output/mammo-net-2MLPmodel/best-2MLPmodel-epoch=04-val_auc=0.82.ckpt
# >>> Running Final Test for 2MLPmodel
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_auc          │    0.7956787347793579     │
# │         test_loss         │    0.9635189175605774     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# ## **Part C**: Conduct a subgroup performance analysis.

# %% [markdown]
# The code below allows you to check the model performance by plotting the [ROC curves](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html) and calculating the per-class [AUC](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html) metrics over the whole test set.
#
# **TASK:** Using different attributes from the meta information, conduct several subgroup performance analyses, and report the results in the coursework report. Note any interesting observations.

# %%
df_pred = pd.read_csv(os.path.join(output_dir, 'predictions.csv'))

# %%
class_columns = [col for col in df_pred.columns if col.startswith('class_')]
preds = np.stack([df_pred[col] for col in class_columns]).T
targets = np.array(df_pred['target'])

roc_results = {}

for i, class_name in enumerate(class_columns):
    pos_label = i
    y = np.array(targets)
    y[targets != pos_label] = 0
    y[targets == pos_label] = 1

    fpr, tpr, _ = roc_curve(y, preds[:, pos_label])
    roc_auc = auc(fpr, tpr)

    roc_results[class_name] = {
        'fpr': fpr,
        'tpr': tpr,
        'roc_auc': roc_auc
    }

# %%
fig, ax = plt.subplots(figsize=(7, 4))

for i, (class_name, metrics) in enumerate(roc_results.items()):
    label = f"Class {i} AUC={metrics['roc_auc']:.2f}"
    plt.plot(metrics['fpr'], metrics['tpr'], lw=1.5, alpha=.8, label=label)

ax.plot([0, 1], [0, 1], linestyle='--', lw=1.5, color='k', label='Chance', alpha=.8)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.legend(loc="lower right", fontsize=12)
plt.title('Classification Performance', fontsize=14)
ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05])
ax.spines[['right', 'top']].set_visible(False)
plt.tight_layout()

# %% [markdown]
# ## **Part D**: Inspect the trained model by analysing feature embeddings.

# %% [markdown]
# ### Extract embeddings
#
# We first need to extract the feature embeddings from the classification model.
#
# **TASK:** Adapt the code below and make it work for your classification model. You only need to adapt the functions `on_test_epoch_start` and `test_step`.

# %%
# derived class to extract embeddings for visualization in addition to predictions
class MammoNetEmbeddings(MammoNet):
    def __init__(self, num_classes, learning_rate=0.0001):
        super().__init__(num_classes, learning_rate)
        self.embeddings = [] # list where we still store the embeddings

    def on_test_epoch_start(self):
        self.model[2] = nn.Identity(512) # replace final classification layer with identity to get embeddings
        self.embeddings = [] # clear the list of embeddings at the start of testing

    def test_step(self, batch, batch_idx):
        x = batch['image'].view(batch['image'].size(0), -1)
        emb = self.model(x)
        self.embeddings.append(emb.detach().cpu())

    # Override to disable other test logging of base class
    def on_test_epoch_end(self):
        return

# %%
def save_embeddings(model, output_fname):
    embeddings = torch.cat(model.embeddings, dim=0).cpu().numpy()
    df = pd.DataFrame(data=embeddings)
    df.to_csv(output_fname, index=False)

# %%
model_emb = MammoNetEmbeddings(num_classes=NUM_CLASSES)
trainer.test(model=model_emb, datamodule=data, ckpt_path=trainer.checkpoint_callback.best_model_path)
save_embeddings(model=model_emb, output_fname=os.path.join(output_dir, 'embeddings.csv'))

# %% [markdown]
# ### Model inspection
#
# Now that we extracted the feature embeddings for the test set, we can combine this information with the meta data and the model predictions.
#
# **TASK:** Adapt the provided code to conduct a model inspection, using different projections from different dimensionality reduction techniques, and overlay different types of meta information. Report the your findings in the coursework report. Note any interesting observations.

# %%
df_meta = pd.read_csv(CSV_FILE)
df_pred = pd.read_csv(os.path.join(output_dir, 'predictions.csv'))
df = pd.merge(df_pred, df_meta, how='inner', on=['image_id', 'study_id'])

# %%
embeddings = pd.read_csv(os.path.join(output_dir, 'embeddings.csv')).to_numpy()
print(embeddings.shape)

# %% [markdown]
# Next, we run PCA to reduce the dimenionality of the feature embeddings.

# %%
pca = decomposition.PCA(n_components=4, whiten=False)
embeddings_pca = pca.fit_transform(embeddings)

print(embeddings_pca.shape)

# %%
df['pca_1'] = embeddings_pca[:,0]
df['pca_2'] = embeddings_pca[:,1]
df['pca_3'] = embeddings_pca[:,2]
df['pca_4'] = embeddings_pca[:,3]

# %%
embeddings_tsne = TSNE(n_components=2, init='random', learning_rate='auto').fit_transform(embeddings_pca)

print(embeddings_tsne.shape)

# %%
df['tsne_1'] = embeddings_tsne[:,0]
df['tsne_2'] = embeddings_tsne[:,1]

df.head() # showing the first five entries in the dataframe

# %%
## shuffle the dataframe to ensure random order of samples for visualization
df = df.sample(frac=1.0)

# %%
alpha = 0.6
style = '.'
markersize = 40
color_palette = 'tab10'
kind = 'scatter'

def plot_scatter(data, hue, x, y, palette):
    hue_order = list(data[hue].unique())
    hue_order.sort()
    sns.set_theme(style="white")
    ax = sns.scatterplot(data=data, x=x, y=y, hue=hue, hue_order=hue_order, alpha=alpha, marker=style, s=markersize, palette=palette)
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

def plot_joint(data, hue, x, y, palette):
    hue_order = list(data[hue].unique())
    hue_order.sort()
    sns.set_theme(style="white")
    ax = sns.jointplot(data=data, x=x, y=y, hue=hue, hue_order=hue_order, alpha=alpha, marker=style, s=markersize, palette=palette, marginal_kws={'common_norm': False})
    sns.move_legend(ax.ax_joint, "upper left", bbox_to_anchor=(1.2, 1))

# %%
x = 'pca_1'
y = 'pca_2'

# %%
plot_joint(df, 'density', x, y, color_palette)

# %% [markdown]
# ### Interactive visualisation

# %% [markdown]
# With the code below you can interactively explore the latent space to better understand how samples are distributed. You can modify the code to overlay different types of meta information.

# %%
df["image_path"] = [
    os.path.join("images", str(df.study_id.values[idx]), str(df.image_id.values[idx]) + ".png")
    for idx in range(len(df))
]

df['color_label'] = 0
df.loc[df['density'] == 'A', 'color_label'] = 0
df.loc[df['density'] == 'B', 'color_label'] = 1
df.loc[df['density'] == 'C', 'color_label'] = 2
df.loc[df['density'] == 'D', 'color_label'] = 3

# %%
def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(rgb[0], rgb[1], rgb[2])

color = cm.tab10(np.linspace(0, 1, 10))
colorlist = [(np.array(mpl.colors.to_rgb(c))*255).astype(int).tolist() for c in color]*10

colors = [rgb_to_hex(colorlist[c]) for c in df.color_label.values]

# %%
def preprocess(image):
    # breast mask
    image_norm = image - np.min(image)
    image_norm = image_norm / np.max(image_norm)
    thresh = cv2.threshold(img_as_ubyte(image_norm), 5, 255, cv2.THRESH_BINARY)[1]

    # Connected components with stats.
    nb_components, output, stats, _ = cv2.connectedComponentsWithStats(thresh, connectivity=4)

    # Find the largest non background component.
    # Note: range() starts from 1 since 0 is the background label.
    max_label, _ = max(
        [(i, stats[i, cv2.CC_STAT_AREA]) for i in range(1, nb_components)],
        key=lambda x: x[1],
    )
    mask = output == max_label
    image_masked = image.copy()
    image_masked[mask == 0] = 0

    return image_masked

# %%
out = Output()
@out.capture(clear_output=True)
def handle_click(trace, points, state):
    sample = df.iloc[points.point_inds[0]]
    img_orig = imread(os.path.join(DATA_DIR, sample.image_path))
    img_proc = preprocess(img_orig)
    
    s = [6] * len(df)
    for i in points.point_inds:
        s[i] = 12
    with fig.batch_update():
        scatter.marker.size = s

    f, (ax1, ax2) = plt.subplots(1,2, figsize=(8,8))
    ax1.imshow(img_orig, cmap='gray')
    ax1.set_title('original')
    ax1.axis('off')
    ax2.imshow(img_proc, cmap='gray')
    ax2.set_title('processed')
    ax2.axis('off')
    plt.show(f)
    
fig = go.FigureWidget(px.scatter(df, x=x, y=y, template='simple_white', hover_data={'density': True, x:False, y:False}))
fig.update_layout(width=600, height=600)
scatter = fig.data[0]
scatter.on_click(handle_click)
scatter.marker.size = [6] * len(df)
scatter.marker.color = colors

HBox([fig, out])
